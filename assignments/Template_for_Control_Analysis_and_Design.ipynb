# %% [markdown]
# # TEMPLATE FOR CONTROL ANALYSIS AND DESIGN

# %% [markdown]
# This notebook is a template for the analysis and design of a chemical system for control design.

# %% [markdown]
# # System Description and Control Objectives

# %% [markdown]
# You are describing the chemical system to regulate and the reason for doing the regulation. In control parlance, this is the **open loop system** (or plant).

# %% [markdown]
# 1. What is the open loop system? Provide a pointer to its SBML model (most likely in BioModels).
# 1. What is the output you want to control (**measured output**)?
# 1. Requirements for effective control.
#     1. How accurately must the controller track the objective (**bias**)?
#     1. How quickly must the controller adjust after a disruption (**settling times**)?
#     1. Tolerance of oscillations, overshoot, undershoot?

# %% [markdown]
# # Controllability

# %% [markdown]
# Controllability is about the extent to which a species in the chemical system can be used to change the measured output.
#
# 1. What is being regulated to control the output?
# 1. Is this regulation an activator or an inhibitor of the output?
# 1. Operating region
#     1. Range of values of the output?
#     1. Range of values of the input?
# 1. Effectiveness of control
#     1. How much is the output influenced by the input over the operating region?
#     1. How long are the settling times?
#     1. What transient are present such as oscillations or potential instabilities?

# %% [markdown]
# # System Identification

# %% [markdown]
# System identifical is about constructing a transfer function that approximates the effect of the control input on the measured output. You will construct a transfer function $G(s)$ that is the ratio of the Laplace transfer of the measured output ($Y(s)$) to the Laplae transform of the control input ($U(s)$). You will compare these predictions with those obtained from simulation.

# %% [markdown]
# 1. How well does your fitted transfer function predict the behavior of the system?
# 1. Assess the following:
#     1. How much does the model improved if you increase the order of the transfer function.
#     1. How much does the model degrade if you decrease the order of the transfer function.
# 1. From your transfer function,
#     1. What are the poles?
#     1. What do the poles tell you about oscillations?
#     1. What do the poles tell you about BIBO (bounded input, bounded output) stability?

# %% [markdown]
# # Control Design

# %% [markdown]
# 1. Show the design you obtain from root locus analysis.
#     1. How did you navigate the branches of the root locus diagram?
#     1. Why did you choose a particular position on a root locus branch?
# 1. Compare the design from root locus with the simulation of the closed loop system for that design. How accurately did the model predict behavior (both quantitatively and qualitatively).
# 1. Compare your chosen design with one other design. For example, if your chosen design is a PI controller, then compare with a P or PID controller.

# %% [markdown]
# # Proposal and qualifications

# %% [markdown]
# Make your recommendations for control design and your qualifications (e.g., the impact of going outside the operating region).
