# %% [markdown]
# # HOMEWORK 3 - CONTROL DESIGN
# ## Cirstyn Michel

# %% [markdown]
# **Comments**
# 1. Nice job. 100 pts.

# %% [markdown]
# In this homework, you will do a complete narrative for control design for your system.
# You can use the notebook for lecture 15 (Workflow for control design) as a guide to what is expected.

# %% [markdown]
# # Preliminaries

# %%
import collections
import control
import controlSBML as ctl
import lmfit
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sympy
import tellurium as te

# %% [markdown]
# # Helpers

# %%
bsubtilus_CTLSB = ctl.ControlSBML("https://www.ebi.ac.uk/biomodels/model/download/BIOMD0000001053.2?filename=Garde2020.xml", 
                        input_names=["Ai"], output_names=["Gp"])
bsubtilus_sys = bsubtilus_CTLSB.makeNonlinearIOSystem("bsubtilus_sys")
LINEAR_BLDR = bsubtilus_CTLSB.makeSISOTransferFunctionBuilder()

# %%
TIMES = np.linspace(0, 10, 100)

# %%
TEST_MODEL = """
species S1, S2, S3

S1 -> S2; k1*S1
S2 -> S3; k2*S2

S1 = 10
S2 = 0
S3 = 0
k1 = 1
k2 =2
"""
TEST_CTLSB = ctl.ControlSBML(TEST_MODEL, input_names=["S1"], output_names=["S3"])
TEST_SYS = TEST_CTLSB.makeNonlinearIOSystem("TEST_SYS")

# %%
class PlotResult(object):
    def __init__(self, times = None, y_arr=None, ax=None):
        self.times = times
        self.y_arr = y_arr
        self.ax = ax
        
    def __repr__(self):
        return ""

# %%
# This class captures the results of a designing a closed loop system
class DesignResult(object):
    def __init__(self, grm=None, gnm=None, params=None, det=None):
        """
        Parameters
        ----------
        grm: control.TransferFunction
        gnm: control.TransferFunction
        params: lmfit.Parameters
        det: lmfit.MinimizerResult
        
        """
        self.grm = grm
        self.gnm = gnm
        self.params = params
        self.det = det
        
    def __repr__(self):
        return ""

# %% [markdown]
# ## ``plotSys``

# %%
def plotSys(sys, times=None, initial_values=None, forced_input=None,
            title="", ax=None, output_labels=None, figsize=None,
            ylim=None, is_legend=True, is_plot=True):
    """
    Plots the system, either a NonlinearIOSystem or a TransferFunction.
    
    Parameters
    ----------
    sys: NonlinearIOSystem or TransferFunction
    times: list-float (times for simulation)
    initial_values: list-float
    forced_input: list-float (default is step)
    figsize: (int, int)
    ax: matplotlib.Axes
    output_labels: list-str (names for output labels)
    title: str (plot title)
    is_legend: bool (include legend)
    
    Returns
    -------
    PlotResut
    """
    if "TransferFunction" in str(type(sys)):
        is_nonlinear = False
    else:
        is_nonlinear = True
    if times is None:
        times = TIMES
    if forced_input is None:
        ncol = len(times)
        nrow = len(sys.input_labels)
        forced_input = np.array([np.repeat(1, nrow) for _ in range(ncol)])
        forced_input = np.reshape(forced_input, (nrow, ncol))
    if (initial_values is None) and is_nonlinear:
        initial_values = ctl.makeStateVector(sys)
    if figsize is None:
        figsize = (5, 5)
    if ax is None:
        _, ax = plt.subplots(1, figsize=figsize)
    if output_labels is None:
        if len(sys.output_labels) == 1:
            output_labels = ["y"]
        else:
            output_labels = list(sys.output_labels)
    # Simulate the system
    if is_nonlinear:
        t, y = control.input_output_response(sys, times, forced_input, initial_values)
    else:
        t, y = control.forced_response(sys, T=times, U=forced_input)
    # Plot the response
    num_output = len(output_labels)
    if num_output == 1:
        if y.ndim == 1:
            plt.plot(t, y)
        else:
            for idx in range(num_output):
                plt.plot(t, y[idx])
    else:
        for idx in range(num_output):
            ax.plot(t, y[idx])
    if is_legend:
        ax.legend(output_labels)
    ax.set_xlabel("time")
    ax.set_title(title)
    if ylim is not None:
        ax.set_ylim(ylim)
    if not is_plot:
        plt.close()
    return PlotResult(times=t, y_arr=y, ax=ax)
    
# Tests
times = T = np.linspace(0, 70, 500)
plot_result = plotSys(TEST_SYS, times, is_plot=False)
assert(len(plot_result.times) == len(plot_result.y_arr))
#
numerator = 5
tf = control.TransferFunction([numerator], [1])
plot_result = plotSys(tf, times, forced_input=1, is_plot=False)
assert(len(plot_result.times) == len(plot_result.y_arr))
assert(plot_result.y_arr[0] == numerator)
print("OK!")
# Out:
# OK!

# %% [markdown]
# ## ``makeDerivative``

# %%
def makeDerivative():
    """
    Returns a funtion that calculates derivatives for a signal.
    
    Returns
    -------
    Function
    """ 
    class Last():
        def __init__(self, t, u):
            self.t = t
            self.u = u
    #
    last = Last(0, 0)
    # Calculate derivative of the input
    def derivative(t, u):
        """
        Parameters
        ----------
        t: float
        u: float
        
        Returns
        -------
        float
        """
        dt = t - last.t
        if dt <= 0:
            du = 0
        else:
            du = (u - last.u)/dt
        last.t = t
        last.u = u
        return du
    #
    return derivative

# Tests
is_plot = False
derivative = makeDerivative()
inputs = np.sin(TIMES)
outputs = [derivative(t, 1) for t in TIMES]
np.allclose(outputs, 0)
#
derivative = makeDerivative()
inputs = np.sin(TIMES)
outputs = [derivative(t, i) for t, i in zip(TIMES, inputs)]
derivative = makeDerivative()
second_inputs = list(outputs)
outputs = [derivative(t, i) for t, i in zip(TIMES, second_inputs)]
if is_plot:
    plt.plot(TIMES, inputs, color="black")
    plt.plot(TIMES, outputs, color="red")
print("OK")
# Out:
# OK

# %% [markdown]
# ## ``makeCLTransferFunctions``

# %%
# grm: G_RM
# gnm: G_NM
# gf: Filter
# gc: Controller
# go: OLS
CLTransferFunctions = collections.namedtuple("CLTransferFunctions",
      "grm gnm gc gf go")
def makeCLTransferFunctions(gO_tf, params, is_warnings=True):
    """
    Makes two closed loop transfer functions.
        G_RM (s) - transfer function from the reference input to the measurement output
        G_NM (s) - transfer function from the noise input to the measurement output
    
    Parameters
    ----------
    gO_tf: control.TransferFunction (open loop transfer function)
    params:
        kP: float (set to 0 if parameter is not present)
        kI: float (set to 0 if parameter is not present)
        kD: float (set to 0 if parameter is not present)
        kF: float (no filter if parameter is absent)
        is_warnings: bool (display warnings)
    
    Returns
    -------
    CLTransferFunctions
    """
    # Extract the parameters if they are present
    if "kP" in params.keys():
        kP = params["kP"].value
    else:
        kP = 0
    if "kI" in params.keys():
        kI = params["kI"].value
    else:
        kI = 0
    if "kD" in params.keys():
        kD = params["kD"]. value
    else:
        kD = 0
    if "kDD" in params.keys():
        kDD = params["kDD"]. value
    else:
        kDD = 0
    if "kF" in params.keys():
        kF = params["kF"].value
    else:
        kF = None
    # Construct PI Controller
    gC_tf = control.TransferFunction([kP], [1]) 
    gC_tf = gC_tf + control.TransferFunction([kI], [1, 0])
    gC_tf = gC_tf + control.TransferFunction([kD, 0], [1])
    gC_tf = gC_tf + control.TransferFunction([kDD, 0, 0], [1])
    # Construct Filter
    if kF is not None:
        gF_tf = control.TransferFunction([kF], [1, kF])
    else:
        gF_tf = control.TransferFunction([1], [1])
    # RM Closed loop Transfer function
    gRM_tf = control.feedback(gC_tf*gO_tf, sys2=gF_tf)
    # NM Closed loop Transfer function
    gNM_tf = control.feedback(1, sys2=gC_tf*gO_tf*gF_tf)
    # Check for improper transfer functions
    for tf_str in ["gRM_tf", "gNM_tf", "gC_tf", "gF_tf", "gO_tf"]:
        tf = eval(tf_str)
        num_dim = np.shape(tf.num)[-1]
        den_dim = np.shape(tf.den)[-1]
        if num_dim > den_dim:
            if is_warnings:
                print("***Warning. %s is an improper transfer function" % tf_str)
    #
    return CLTransferFunctions(grm=gRM_tf, gnm=gNM_tf, gc=gC_tf, gf=gF_tf, go=gO_tf)

# This test generates several warnings
is_plot = False
tf = control.TransferFunction([1], [1, 1])
params = lmfit.Parameters()
params.add("kP", value=1)
params.add("kI", value=1)
params.add("kD", value=1)
params.add("kDD", value=1)
cltf = makeCLTransferFunctions(tf, params, is_warnings=is_plot)
assert(isinstance(cltf.grm, control.TransferFunction))
assert(isinstance(cltf.gnm, control.TransferFunction))
assert(isinstance(cltf.gc, control.TransferFunction))
dummy_tf = cltf.gc*control.TransferFunction([1], [1, 1, 1]) # Ensure proper Transfer function
_ = plotSys(dummy_tf, forced_input=1, is_plot=is_plot)
plot_response = plotSys(cltf.grm, is_plot=is_plot)
plot_response = plotSys(cltf.gnm, is_plot=is_plot)
# 
params.add("kF", value=1)
cltf = makeCLTransferFunctions(tf, params, is_warnings=is_plot)
assert(isinstance(cltf.grm, control.TransferFunction))
assert(isinstance(cltf.gnm, control.TransferFunction))
assert(isinstance(cltf.gc, control.TransferFunction))
print("OK!")
# Out:
# OK!

# %% [markdown]
# ## ``designClosedLoop``

# %%
def designClosedLoop(open_loop_tf, is_kP=True, is_kI=True, is_kD=True, is_kDD=False,
                     is_kF=True, amp=1, times=TIMES, kmax=1e4, is_warnings=True):
    """
    Finds parameters for the closed loop system that eliminate noise and have a good step response.
    By default the closed loop system has a PID controller and a filter. By changing is_<k>,
    you can select variations in the design.
    
    Paramters
    ---------
    open_loop_tf: control.TransferFunction (OLS transfer function)
    is_<k>: bool (include the design element)
    amp: 0 <=float  (amplitude of the sine wave used to evaluate noise response)
    times: array-float
    kmax: float (maximum value of a constant)
    
    Returns
    -------
    DesignResult
    """
    NOISE_FREQ = 20*2*np.pi
    step_inputs = np.repeat(1, len(times))
    ideal_step_outputs = step_inputs
    noise_inputs = amp*np.sin(NOISE_FREQ*times) # Sinusoid input
    ideal_noise_outputs = np.repeat(0, len(times))
    def calculateDesignResiduals(params):
        """
        Calculates the residuals with an ideal step response.

        Parameters
        ----------
        params: lmfit.Parameters

        Returns
        -------
        array-float
        """
        cltf = makeCLTransferFunctions(open_loop_tf, params, is_warnings=is_warnings)
        gRM_tf, gNM_tf = (cltf.grm, cltf.gnm)
        # Calculate residuals for a step response
        _, step_est = control.forced_response(gRM_tf, T=times, U=1)
        step_residuals = ideal_step_outputs - step_est
        # Calculate residuals for a sinusoidal noise input
        _, sinusoid_est = control.forced_response(gNM_tf, T=times, U=noise_inputs)
        sinusoid_residuals = ideal_noise_outputs - sinusoid_est
        #
        return step_residuals + sinusoid_residuals
    # 
    params = lmfit.Parameters()
    if is_kP:
        params.add("kP", value=1, min=0, max=kmax)
    if is_kI:
        params.add("kI", value=1, min=0, max=kmax)
    if is_kD:
        params.add("kD", value=1, min=0, max=kmax)
    if is_kDD:
        params.add("kDD", value=1, min=0, max=kmax)
    if is_kF:
        params.add("kF", value=1, min=0, max=kmax)
    minimizer_result = lmfit.minimize(calculateDesignResiduals, params)
    new_params = minimizer_result.params
    #
    cltf = makeCLTransferFunctions(gO_tf, new_params, is_warnings=is_warnings)
    gRM_tf, gNM_tf = (cltf.grm, cltf.gnm)
    design_result = DesignResult(grm=gRM_tf, gnm=gNM_tf, params=new_params, det=minimizer_result)
    return design_result

# Tests
is_plot = False
gO_tf = control.TransferFunction([1], [1, 1, 1])
design_result = designClosedLoop(gO_tf, kmax=1e10, amp=10, is_kD=True, is_kDD=False, is_warnings=False)
times = np.linspace(0, 10, 100)
noise_inputs = np.sin(20*2*np.pi*times) # Sinusoid i
plotSys(design_result.gnm, times=times, ylim=[-1, 1],
                                          forced_input=noise_inputs, is_plot=is_plot)
assert(isinstance(design_result.grm, control.TransferFunction))
print("OK!")
# Out:
# OK!

# %% [markdown]
# ## ``plotDesignResult``

# %%
# Plots of the transfer functions
def plotDesignResult(design_result, ax=None, end_time=50, title="", is_plot=True, **kwargs):
    """
    Plots a DesignResult.
    
    Parameters
    ----------
    design_result: DesignResult
    ax: Matplotlib.Axes
    end_time: float
    is_plot: bool
    kwargs: dict (other plotting options)
    """
    if ax is None:
        if "figsize" in kwargs.keys():
            figsize = kwargs["figsize"]
        else:
            figsize = (3, 3)
        _, ax = plt.subplots(1, figsize=figsize)
    times = np.linspace(0, end_time, 2000)
    plot_result1 = plotSys(design_result.grm, forced_input=1, times=times, ax=ax,
                         is_legend=False)
    plot_result2 = plotSys(design_result.gnm, forced_input=np.sin(5*times), times=times, 
            is_legend=False, ax=ax)
    if "ylim" in kwargs.keys():
        ylim = kwargs["ylim"]
    else:
        ylim = ax.set_ylim()
    xpos = end_time*1.1
    yspan = ylim[1] - ylim[0]
    ypos1 = ylim[1] - 0.1*yspan
    ypos2 = ypos1 - 0.2*yspan
    ax.text(xpos, ypos1, "G_RM", c="blue")
    ax.text(xpos, ypos2, "G_NM", c="orange")
    ax.set_ylim(ylim)
    ax.set_title(title)
    if not is_plot:
        plt.close()
 
# Tests
plotDesignResult(design_result, kmax=1, figsize= (2,2), is_plot=False, end_time=5)
print("OK!")
# Out:
# OK!

# %% [markdown]
# ## ``plotStaircaseResponse``

# %%
def plotStaircaseResponse(builder, is_plot=True, **kwargs):
    """
    This function circumvents a bug in SISOTransferFunctionBuilder.plotStairCaseResponse.
    It has the same arguments and return value as the original function.
    """
    plot_result = builder.plotStaircaseResponse(is_plot=False, **kwargs)
    # Plot if requested
    if is_plot:
        times = np.array(plot_result.time_series.index)/1000
        df = pd.DataFrame(plot_result.time_series)
        df.index = times
        if "figsize" in kwargs.keys():
            figsize = kwargs["figsize"]
        else:
            figsize = (10, 10)
        legends = list(df.columns)
        fig, ax = plt.subplots(1, figsize=figsize)
        staircase_column = [c for c in df.columns if "staircase" in c][0]
        staircase_values = df[staircase_column].values
        del df[staircase_column]
        ax.plot(df)
        ax2 = ax.twinx()
        # Plot the staircase
        ax2.plot(times, staircase_values, color="red",
              linestyle="--")
        ax2.set_ylabel(staircase_column, color="red")
        ax.legend(df.columns)
    #
    return plot_result

# TESTS
plot_response = plotStaircaseResponse(LINEAR_BLDR, initial_value=2, final_value=10, num_step=5, figsize=(3,3),
                                    legend_crd=(0.5, 1), end_time=100, is_plot=False)
assert(isinstance(plot_response.time_series, ctl.Timeseries))
print("OK!")
# Out:
# OK!

# %% [markdown]
# ## ``makePIController``

# %%
def makePIController(kP=20, kI=10):
    """
    Makes a PI controller with control error as input
    
    Parameters
    ----------
    kP: float
    kI: float
    
    Returns
    -------
    NonlinearIOSystem
    """
    # Calculate derivative of state
    def updfcn(t, x, u, _):
        # Accumulate the control error
        # t: float (time)
        # x: array-float (state)
        # u: array-float (control error)
        # returns: array-float (derivative of state)
        return u[0]

    # Calculate output value
    def outfcn(t, x, u, _):
        # Calculate the output from the input
        # t: float (time)
        # x: array-float (state)
        # u: array-float (inputs)
        # returns: array (output)
        output = kI*x[0] + kP*u[0]
        return output

    controller = control.NonlinearIOSystem(
      updfcn,
      outfcn,
      states=1,
      inputs=['in'],
      outputs=['out'], name='controller_sys')
    return controller

# Tests
kP = 10
kI = 20
controller_sys = makePIController(kP=kP, kI=kI)
assert("NonlinearIOSystem" in str(type(controller_sys)))
plot_result = plotSys(controller_sys, forced_input=[1], is_plot=False)
data = plot_result.y_arr
assert(data[0] == kP)
assert(np.isclose(data[-1], kP + plot_result.times[-1]*kI))
print("OK")
# Out:
# OK

# %% [markdown]
# ## ``makePIDController``

# %%
def makePIDController(kP=20, kI=10, kD=0, kDD=0):
    """
    Makes a PI controller with control error as input
    
    Parameters
    ----------
    kP: float
    kI: float
    kD: float
    kDD: float (coefficient for second derivative of input)
    
    Returns
    -------
    NonlinearIOSystem
    """
    derivative1 = makeDerivative()
    derivative2 = makeDerivative()
    # Calculate derivative of state
    def updfcn(t, x, u, _):
        # Accumulate the control error
        # t: float (time)
        # x: array-float (sum of input, last input)
        # u: array-float (control error)
        # returns: array-float (derivative of state)
        return u[0]

    # Calculate output value
    def outfcn(t, x, u, _):
        # Calculate the output from the input
        # t: float (time)
        # x: array-float (state)
        # u: array-float (inputs)
        # returns: array (output)
        du = derivative1(t, u[0])
        ddu = derivative2(t, du)
        output = kP*u[0] + kI*x[0] + kD*du + kDD*ddu
        return output

    controller = control.NonlinearIOSystem(
      updfcn,
      outfcn,
      states=1,
      inputs=['in'],
      outputs=['out'], name='controller_sys')
    return controller

# Tests
is_plot = False
kP = 10
kI = 20
kD = 100
controller_sys = makePIDController(kP=kP, kI=kI, kD=0)
assert("NonlinearIOSystem" in str(type(controller_sys)))
plot_result = plotSys(controller_sys, forced_input=[1], is_plot=is_plot)
data = plot_result.y_arr
assert(data[0] == kP)
assert(np.isclose(data[-1], kP + plot_result.times[-1]*kI))
#
controller_sys = makePIDController(kP=kP, kI=kI, kD=kD, kDD=10)
inputs = np.sin(TIMES)
plot_result = plotSys(controller_sys, forced_input=inputs, is_plot=is_plot)

print("OK")
# Out:
# OK

# %% [markdown]
# ## ``makeFilter``

# %%
def makeFilter(system_name="filter_sys", kF=1):
    """
    Makes a filter.
    
    Parameters
    ----------
    system_name: str
    kF: float
    
    Returns
    -------
    NonlinearIOSystem
    """
    # Calculate derivative of state
    def updfcn(t, x, u, _):
        # Accumulate the control error
        # t: float (time)
        # x: array-float (state, averaged signal)
        # u: array-float (control error)
        # returns: array-float (derivative of state)
        dy = kF*u[0] - kF*x[0]
        return dy

    # Calculate output value
    def outfcn(t, x, u, _):
        # Calculate the output from the input
        # t: float (time)
        # x: array-float (state)
        # u: array-float (inputs)
        # returns: array (output)
        return x[0]

    filter_sys = control.NonlinearIOSystem(
      updfcn,
      outfcn,
      states=1,
      inputs=['in'],
      outputs=['out'], name=system_name)
    return filter_sys

# Tests
kF = 1
filter_sys = makeFilter(kF=kF)
assert("NonlinearIOSystem" in str(type(filter_sys)))
plot_result = plotSys(filter_sys, forced_input=[1], times=np.linspace(0, 100, 1000), is_plot=False)
data = plot_result.y_arr
assert(np.abs(data[-1] - 1) < 0.01)
print("OK")
# Out:
# OK

# %% [markdown]
# ## ``makeSinusoid``

# %%
def makeSinusoid(system_name="sinusoid_sys", amplitude=1, frequency=20):
    """
    Makes a sinusoidal signal, the only output.
    
    Parameters
    ----------
    system_name: str
    amplitude: float (amplitude of the sinusoid)
    frequency: float (frequencay of the sinusoid)
    
    Returns
    -------
    NonlinearIOSystem
    """
    # Calculate output value
    def outfcn(t, x, u, _):
        # Calculate the output from the input
        # t: float (time)
        # x: array-float (state)
        # u: array-float (inputs)
        # returns: array (output)
        return amplitude*np.sin(t*2*np.pi*frequency)

    sinusoid_sys = control.NonlinearIOSystem(
      None,
      outfcn,
      inputs=0,
      outputs=['out'],
      name=system_name)
    return sinusoid_sys

# Tests
sinusoid_sys = makeSinusoid(amplitude=10)
assert("NonlinearIOSystem" in str(type(sinusoid_sys)))
plot_result = plotSys(sinusoid_sys, forced_input=1, times=np.linspace(0, 10, 1000), is_plot=False)
count = len([v for v in plot_result.y_arr[0] if v >= 0.999])
assert(count > 1)
print("OK")
# Out:
# OK

# %% [markdown]
# ## ``makeAdder``

# %%
def makeAdder(input_names, output_name="out", system_name="adder_sys"):
    """
    Creates a NonlinearIOSystem that does addition
    of the inputs. Any name that begins wit a "-" is subtracted.
    
    Parameters
    ----------
    input_nmames: list-str
    output_name: str
    system_name: str
    
    Returns
    -------
    NonlinearIOSystem
    """
    adjustments = []
    adjusted_input_names = []
    def outfcn(_, __, u, ___):
        # Calculate the output from the input
        # t: float (time)
        # x: array-float (state)
        # u: array-float (inputs)
        # returns: array (output)
        return adjustments.dot(u)
    #
    for name in input_names:
        if name[0] == "-":
            value = -1
            new_name = name[1:]
        else:
            value = 1
            new_name = name
        adjustments.append(value)
        adjusted_input_names.append(new_name)
    adjustments = np.array(adjustments)
    #
    return control.NonlinearIOSystem(
          None,
          outfcn,
          inputs=adjusted_input_names,
          outputs=output_name, name=system_name)

# Tests
adder_sys = makeAdder(["a", "-b", "c"])
assert("NonlinearIOSystem" in str(type(adder_sys)))
# Simulate to verify 
plot_result = plotSys(adder_sys, forced_input=[3, 2, 4], is_plot=False)
data = plot_result.y_arr
assert(np.var(data[0]) == 0)
assert(data[0][0] == 5)
print("OK")
# Out:
# OK

# %% [markdown]
# ## ``makeClosedLoopSystem``

# %%
def makeClosedLoopSystem(ctlsb, kP=1, kI=1, kF=1, kD=0, kDD=0, noise_amplitude=1,
                         noise_frequency=20):
    """
    Create a closed loop system with a controller and filter for an SBML model.
    
    Parameters
    ----------
    ctlsb: ControlSBML (for open loop system)
    kP: float
    kI: float
    kD: float
    kF: float
    noise_amplitude: float
    noise_frequency: float
    
    Returns
    -------
    Interconnect
    """
    # Information for open loop system
    if len(ctlsb.input_names) != 1:
        raise ValueError("Open loop system should have exactly 1 input")
    if len(ctlsb.output_names) != 1:
        raise ValueError("Open loop system should have exactly 1 output")
    open_sys = ctlsb.makeNonlinearIOSystem("open_sys")
    sinusoid_sys = makeSinusoid(system_name="sinusoid_sys",
                                amplitude=noise_amplitude, frequency=noise_frequency)
    open_input = "open_sys.%s" % ctlsb.input_names[0]
    open_output = "open_sys.%s" % ctlsb.output_names[0]
    # Other elements
    filter_sys = makeFilter(kF=kF)
    controller_sys = makePIDController(kP=kP, kI=kI, kD=kD, kDD=kDD)
    differ_sys = makeAdder(["setpoint", "-measurement"], system_name="differ_sys")
    adder_sys = makeAdder(["noise", "open_sys"], system_name="adder_sys")
    closed_sys = control.interconnect(
      [adder_sys, sinusoid_sys, open_sys, controller_sys, differ_sys, filter_sys],       # systems
      connections=[
        ['adder_sys.noise', "sinusoid_sys.out"],
        ['adder_sys.open_sys', open_output],
        ['filter_sys.in', "adder_sys.out"],
        ['differ_sys.measurement', 'filter_sys.out'],
        ['controller_sys.in',  'differ_sys.out'],
        [open_input, 'controller_sys.out'],
      ],
      inplist=["differ_sys.setpoint"],
      outlist=["adder_sys.out", "controller_sys.out"],
    )
    return closed_sys

# Tests
setpoint = 1
new_closed_sys = makeClosedLoopSystem(TEST_CTLSB, noise_amplitude=1, kP=1, kI=0.1, kD=0.2, kDD=0.1, kF=1000)
assert("Interconnect" in str(type(new_closed_sys)))
plot_result = plotSys(new_closed_sys, forced_input=[setpoint], times=np.linspace(0, 30, 100), 
                      is_plot=False, output_labels=["s5", "control_input"])
data = plot_result.y_arr
assert(data[0][0] == 0)
assert(np.abs(setpoint - data[0][-1]) < 0.2)
print("OK!")
# Out:
# OK!

# %% [markdown]
# # Step 1. Problem Statement (15 pts)

# %% [markdown]
# ## Problem Statement
# Describe the control problem that you are addressing.
#
# The model I chose to work with for these assignments is called "Metabolic Oscillations in Bacillus subtilis Biofilms". Metabolic patterns are still largely misunderstood while B subtilus is in their produced biofilm, but generally, the concentrations of several key metabolites oscillate. As B subtilus is an organism commonly used in industrial applications and biofilm production is often beneficial, I thought this would be an interesting metabolic pattern to attempt to be able to regulate with the addition of easily accessible chemicals. Glutamate production is shown to be linked to biofilm production so I chose to control glutmate with the input of ammonia, a very common feed for bacterial production.

# %% [markdown]
# ## System studied
# Specify the input and output to your system, simulate its open loop behavior, and plot the results.

# %%
bsubtilus_CTLSB = ctl.ControlSBML("https://www.ebi.ac.uk/biomodels/model/download/BIOMD0000001053.2?filename=Garde2020.xml", 
                        input_names=["Ai"], output_names=["Gp"])
bsubtilus_sys = bsubtilus_CTLSB.makeNonlinearIOSystem("bsubtilus_sys")
linear_builder = bsubtilus_CTLSB.makeSISOTransferFunctionBuilder()
ts = ctl.simulateSystem(bsubtilus_sys, end_time=40)
_ = ctl.plotOneTS(ts, figsize=(10,5), ylim=[0, 30])

# %%
print(bsubtilus_CTLSB.antimony)
# Out:
# // Created by libAntimony v2.13.2
# function function_for_biomass_production(k2, Ap, Gp)
#   k2*Ap*Gp;
# end
#
# function_for_biomass_production is "function for biomass production"
#
# function function_for_diffusion_of_Ammonia_from_interior_to_middle_layer(k3, Ai)
#   k3*Ai;
# end
#
# function_for_diffusion_of_Ammonia_from_interior_to_middle_layer is "function for diffusion of Ammonia from interior to middle layer"
#
# function function_for_production_of_Ammonia_using_Glutamate_by_inner_cells(k5, Gi)
#   k5*Gi;
# end
#
# function_for_production_of_Ammonia_using_Glutamate_by_inner_cells is "function for production of Ammonia using Glutamate by inner cells"
#
# function function_Gp_diffusion_to_the_interior_cells(k4, Gp)
#   k4*Gp;
# end
#
# function_Gp_diffusion_to_the_interior_cells is "function Gp diffusion to the interior cells"
#
# function function_for_positive_feedback_of_Gp_on_itself(k1, Ge, Gp)
#   k1*Ge*Gp;
# end
#
# function_for_positive_feedback_of_Gp_on_itself is "function for positive feedback of Gp on itself"
#
# function function_for_ammonia_diffusion_from_middle_layer_to_periphery(k3, Am)
#   k3*Am;
# end
#
# function_for_ammonia_diffusion_from_middle_layer_to_periphery is "function for ammonia diffusion from middle layer to periphery"
#
# function function_for_loss_of_Ammonia_du_to_diffusion_to_the_environment(k3, Ap)
#   k3*Ap;
# end
#
# function_for_loss_of_Ammonia_du_to_diffusion_to_the_environment is "function for loss of Ammonia du to diffusion to the environment"
#
# function function_for_diffusion_of_Glutamate_from_middle_to_interior_layer(k4, Gm)
#   k4*Gm;
# end
#
# function_for_diffusion_of_Glutamate_from_middle_to_interior_layer is "function for diffusion of Glutamate from middle to interior layer"
#
# function function_for_production_of_Ammonia_in_middle_layer_using_glutamate(k5, Gm)
#   k5*Gm;
# end
#
# function_for_production_of_Ammonia_in_middle_layer_using_glutamate is "function for production of Ammonia in middle layer using glutamate"
#
# function function_for_use_of_glutamate_in_middle_layer_for_biomass_production(k2, Am, Gm)
#   k2*Am*Gm;
# end
#
# function_for_use_of_glutamate_in_middle_layer_for_biomass_production is "function for use of glutamate in middle layer for biomass production"
#
#
# model *Garde2020___metabolic_oscillations_in_Bacillus_subtilis_biofilms()
#
#   // Compartments and Species:
#   compartment Biofilm;
#   species Gp in Biofilm, Ai in Biofilm, Am in Biofilm, Ap in Biofilm, Gm in Biofilm;
#   species Gi in Biofilm;
#
#   // Reactions:
#   Positive_feedback_of_Gp_on_itself:  => Gp; Biofilm*function_for_positive_feedback_of_Gp_on_itself(k1, Ge, Gp);
#   Gp_diffusion_to_the_interior_cells: Gp => Gm; Biofilm*function_Gp_diffusion_to_the_interior_cells(k4, Gp);
#   Biomass_production: Gp => ; Biofilm*function_for_biomass_production(k2, Ap, Gp);
#   Diffusion_of_Ammonia_from_interior_to_middle_layer: Ai => Am; Biofilm*function_for_diffusion_of_Ammonia_from_interior_to_middle_layer(k3, Ai);
#   Production_of_Ammonia_using_Glutamate_by_inner_cells: Gi => Ai; Biofilm*function_for_production_of_Ammonia_using_Glutamate_by_inner_cells(k5, Gi);
#   Ammonia_diffusion_from_middle_layer_to_periphery: Am => Ap; Biofilm*function_for_ammonia_diffusion_from_middle_layer_to_periphery(k3, Am);
#   loss_of_Ammonia_du_to_diffusion_to_the_environment: Ap => ; Biofilm*function_for_loss_of_Ammonia_du_to_diffusion_to_the_environment(k3, Ap);
#   Diffusion_of_Glutamate_from_middle_to_interior_layer: Gm => Gi; Biofilm*function_for_diffusion_of_Glutamate_from_middle_to_interior_layer(k4, Gm);
#   Production_of_Ammonia_in_middle_layer_using_glutamate: Gm => Am; Biofilm*function_for_production_of_Ammonia_in_middle_layer_using_glutamate(k5, Gm);
#   Use_of_glutamate_in_middle_layer_for_biomass_production: Gm => ; Biofilm*function_for_use_of_glutamate_in_middle_layer_for_biomass_production(k2, Am, Gm);
#
#   // Species initializations:
#   Gp = 0.999999999999999;
#   Ai = 0.999999999999999;
#   Am = 0.999999999999999;
#   Ap = 0.999999999999999;
#   Gm = 1;
#   Gi = 1;
#
#   // Compartment initializations:
#   Biofilm = 1;
#
#   // Variable initializations:
#   k1 = 0.34;
#   k1 has unit_0;
#   k2 = 5.3;
#   k2 has unit_0;
#   k3 = 4;
#   k3 has unit_1;
#   k4 = 2;
#   k4 has unit_2;
#   k5 = 2.3;
#   k5 has unit_2;
#   Ge = 30;
#   Ge has unit_3;
#
#   // Other declarations:
#   const Biofilm, k1, k2, k3, k4, k5, Ge;
#
#   // Unit definitions:
#   unit length = metre;
#   unit area = metre^2;
#   unit volume = litre;
#   unit time_unit = 3600 second;
#   unit substance = 1e-3 mole;
#   unit unit_0 = litre / (1e-3 mole * 3600 second);
#   unit unit_1 = 1 / 3600 second;
#   unit unit_2 = 1 / 3600 second;
#   unit unit_3 = 1e-3 mole / litre;
#
#   // Display Names:
#   time_unit is "time";
#   unit_0 is "(mmol/l*h)^-1";
#   unit_1 is "h^-1";
#   unit_2 is "1/h";
#   unit_3 is "mmol/l";
#   Positive_feedback_of_Gp_on_itself is "Positive feedback of Gp on itself";
#   Gp_diffusion_to_the_interior_cells is "Gp diffusion to the interior cells";
#   Biomass_production is "Biomass production";
#   Diffusion_of_Ammonia_from_interior_to_middle_layer is "Diffusion of Ammonia from interior to middle layer";
#   Production_of_Ammonia_using_Glutamate_by_inner_cells is "Production of Ammonia using Glutamate by inner cells";
#   Ammonia_diffusion_from_middle_layer_to_periphery is "Ammonia diffusion from middle layer to periphery";
#   loss_of_Ammonia_du_to_diffusion_to_the_environment is "loss of Ammonia du to diffusion to the environment";
#   Diffusion_of_Glutamate_from_middle_to_interior_layer is "Diffusion of Glutamate from middle to interior layer";
#   Production_of_Ammonia_in_middle_layer_using_glutamate is "Production of Ammonia in middle layer using glutamate";
#   Use_of_glutamate_in_middle_layer_for_biomass_production is "Use of glutamate in middle layer for biomass production";
#
#   // SBO terms:
#   k1.sboTerm = 9
#   k2.sboTerm = 9
#   k3.sboTerm = 9
#   k4.sboTerm = 9
#   k5.sboTerm = 9
#
#   // CV terms:
#   Biofilm identity "http://identifiers.org/bto/BTO:0002690"
#   Gp hypernym "http://identifiers.org/chebi/CHEBI:32484"
#   Ai hypernym "http://identifiers.org/chebi/CHEBI:16134"
#   Am hypernym "http://identifiers.org/chebi/CHEBI:16134"
#   Ap hypernym "http://identifiers.org/chebi/CHEBI:16134"
#   Gm hypernym "http://identifiers.org/chebi/CHEBI:32484"
#   Gi hypernym "http://identifiers.org/chebi/CHEBI:32484"
#   k1 identity "http://identifiers.org/sbo/SBO:0000009"
#   k2 identity "http://identifiers.org/sbo/SBO:0000009"
#   k3 identity "http://identifiers.org/sbo/SBO:0000009"
#   k4 identity "http://identifiers.org/sbo/SBO:0000009"
#   k5 identity "http://identifiers.org/sbo/SBO:0000009"
#   Ge hypernym "http://identifiers.org/sbo/SBO:0000299"
#   Positive_feedback_of_Gp_on_itself hypernym "http://identifiers.org/sbo/SBO:0000393"
#   Positive_feedback_of_Gp_on_itself hypernym "http://identifiers.org/ncit/C82652"
#   Gp_diffusion_to_the_interior_cells hypernym "http://identifiers.org/ncit/C82333"
#   Gp_diffusion_to_the_interior_cells hypernym "http://identifiers.org/go/GO:0022803"
#   Biomass_production hypernym "http://identifiers.org/sbo/SBO:0000393"
#   Diffusion_of_Ammonia_from_interior_to_middle_layer identity "http://identifiers.org/go/GO:0022803"
#   Diffusion_of_Ammonia_from_interior_to_middle_layer hypernym "http://identifiers.org/ncit/C82333"
#   Production_of_Ammonia_using_Glutamate_by_inner_cells hypernym "http://identifiers.org/sbo/SBO:0000393"
#   Ammonia_diffusion_from_middle_layer_to_periphery hypernym "http://identifiers.org/sbo/GO:0022803"
#   Ammonia_diffusion_from_middle_layer_to_periphery hypernym "http://identifiers.org/sbo/C82333"
#   loss_of_Ammonia_du_to_diffusion_to_the_environment hypernym "http://identifiers.org/sbo/GO:0022803"
#   loss_of_Ammonia_du_to_diffusion_to_the_environment hypernym "http://identifiers.org/sbo/C82333"
#   Diffusion_of_Glutamate_from_middle_to_interior_layer hypernym "http://identifiers.org/sbo/GO:0022803"
#   Diffusion_of_Glutamate_from_middle_to_interior_layer hypernym "http://identifiers.org/sbo/C82333"
#   Production_of_Ammonia_in_middle_layer_using_glutamate hypernym "http://identifiers.org/sbo/SBO:0000393"
#   Use_of_glutamate_in_middle_layer_for_biomass_production hypernym "http://identifiers.org/sbo/SBO:0000393"
# end
#
# Garde2020___metabolic_oscillations_in_Bacillus_subtilis_biofilms is "Garde2020 - metabolic oscillations in Bacillus subtilis biofilms"
#
# Garde2020___metabolic_oscillations_in_Bacillus_subtilis_biofilms model_entity_is "http://identifiers.org/biomodels.db/MODEL2204180002",
#                                                                                  "http://identifiers.org/biomodels.db/BIOMD0000001053"
# Garde2020___metabolic_oscillations_in_Bacillus_subtilis_biofilms container "http://identifiers.org/bto/BTO:0002690"
# Garde2020___metabolic_oscillations_in_Bacillus_subtilis_biofilms taxon "http://identifiers.org/taxonomy/1423"
# Garde2020___metabolic_oscillations_in_Bacillus_subtilis_biofilms description "http://identifiers.org/doi/10.1038/s41598-020-62526-6"
# Garde2020___metabolic_oscillations_in_Bacillus_subtilis_biofilms property "http://identifiers.org/go/GO:0008152",
#                                                                           "http://identifiers.org/go/GO:0019222",
#                                                                           "http://identifiers.org/mamo/MAMO_0000046"

# %%
bsubtilus_RR = bsubtilus_CTLSB.roadrunner
data = bsubtilus_RR.simulate(0, 40, 4000)
plot = bsubtilus_RR.plot(data,figsize=(15,5))

# %% [markdown]
# ## Control objectives
# State the control objectives
#
# Control y(t) = Gp (mmol of Glutamate) using u(t) = Ai (mmol of Ammonia) in bacilus subtilus model.
#
# 1. Eliminate/reduce magnitude of the oscillations in ``Gp``
# 2. Coverge to 10 mMol.

# %% [markdown]
# ## Controllability and operating region
# 1. Do a staircase plot of the control input's effect on the measured output from your system.
# 1. Determine the operating region, the range of (control) inputs to your system that you will use.

# %%
linear_builder = bsubtilus_CTLSB.makeSISOTransferFunctionBuilder()
plotStaircaseResponse(linear_builder, initial_value=2, final_value=1000, num_step=5, figsize=(3,3),
                                    legend_crd=(0.5, 1), end_time=50)

# %% [markdown]
# # Step 2. System Identification (15 pts)

# %% [markdown]
# Here, we estimate a transfer function for the system over the operating range.

# %% [markdown]
# ## Estimated transfer function

# %% [markdown]
# 1. Estimate the transfer function over the operating range and evaluate the quality of the estimate by plotting the
# true system output and the output predicted by the transfer function.
# 1. Show the transfer function.

# %%
def testTransferFunction(num_degree, denom_degree, final_value, end_time):
    fitter_result = linear_builder.fitTransferFunction(num_degree + 1, denom_degree + 1, 
                                                       final_value=final_value,
                                                       initial_value=0, end_time=end_time)
    ctl.plotOneTS(fitter_result.time_series, figsize=(3,3), legend_crd=(2,1))
    ctl.plotOneTS(fitter_result.time_series[["Gp","predicted"]], figsize=(3,3), legend_crd=(2,1))
    #print(fitter_result.transfer_function)
    print(fitter_result.nfev)
    print(fitter_result.redchi)
    return fitter_result

# %%
fitter_result = testTransferFunction(2,4,500,50)
BSUB_TRANSFER_FUNCTION = fitter_result.transfer_function
BSUB_TRANSFER_FUNCTION
# Out:
# 3509
# 108.54937676882373
# TransferFunction(array([ 0.02127687, -0.01381334,  0.02182649]), array([2.29860284e-04, 2.88399035e-01, 2.22568856e-02, 1.60085286e-01,
#        2.14760841e-01]))

# %% [markdown]
# ## Evaluation of the quality of the estimated transfer function

# %%
BSUB_TRANSFER_FUNCTION.poles()
# Out:
# array([-1.25459428e+03+0.j        ,  3.24611012e-01+0.95940555j,
#         3.24611012e-01-0.95940555j, -7.25958675e-01+0.j        ])

# %%
BSUB_TRANSFER_FUNCTION.dcgain()
# Out:
# 0.10163161203684862

# %% [markdown]
# Analyze the expected impact of the accuracy of the transfer function on the closed loop design.
#
# The transfer function is not particularly accurate to the original model but does follow the same basic trends and directionaility in response to increases in Ammonia. You can see that the later time points and higher values of Ammonia are where the transfer function becomes most inaccurate which may result in issues if the amount of ammonia required to reach the desired setpoint falls in that range. Some of the poles are imaginary which indicates is inline with the oscilltory nature of the model. Also the DC gain is relatively small at 0.099 which means that you will need to have a large concentration of input to affect the output even small amounts. Overall, this tranfser function should be adequate to proceed to designing the controller in the closed loop.

# %% [markdown]
# # Step 3. Optimization-Based Control Design (40 pts)

# %% [markdown]
# 1. Designs a closed loop system that achieves our control objectives. By "design" is meant finding values
# of $k_P, k_I, k_D, k_F$.
# 1. Consider noise in the design. Noise is specified by a high frequency sinewave, 20 Hz.

# %%
# Low amp
times = np.linspace(0, 20, 100)
BSUB_DESIGN_RESULT  = designClosedLoop(BSUB_TRANSFER_FUNCTION, kmax=20,
                                       is_kD=True, is_kF=True,
                                 amp=20, times=times, is_warnings=False)
plotDesignResult(BSUB_DESIGN_RESULT, end_time=max(times))

# %% [markdown]
# I was able to reduce the amplitude of the noise during this controller design down to about 0.2 although it does oscilate around 0. I was able to achieve a good G_RM with the desired DC gain of about 1. The optimized kI was found to be relatively 0 which explains the slight offset in DC gain from 1. Overall, this system is suseptible to noise, probably because its prone to oscillation to begin with but using a filter minimzes these affects. The final design controller ended up being essentially a PD controller with a filter after all different iterations of this design were tested. Additionally, I tried to keep the kmax relatively low while still achieving a fast responding system in order to keep the concentrations of input Ammonia feasible.

# %%
BSUB_DESIGN_RESULT.params
# Out:
# Parameters([('kP', <Parameter 'kP', value=19.999999921346472 +/- 11.1, bounds=[0:20]>), ('kI', <Parameter 'kI', value=3.830702643980999e-08 +/- 1.64, bounds=[0:20]>), ('kD', <Parameter 'kD', value=19.999999705993673 +/- 5.44, bounds=[0:20]>), ('kF', <Parameter 'kF', value=19.999444426011287 +/- 127, bounds=[0:20]>)])

# %% [markdown]
# # Step 4. Testbed evaluations (15 pts)

# %% [markdown]
# This step builds a testbed for the system designed in the previous step, and does simulation runs to assess performance relative to the control objectives.

# %%
SETPOINT = 10
BSUB_TIMES = np.linspace(0, 40, 400)

# %% [markdown]
# ## Implementation

# %% [markdown]
# Use the helper ``makeClosedLoopSystem``to do control design. Some iteration may be required.

# %%
bsub_closed_sys = makeClosedLoopSystem(bsubtilus_CTLSB, kP=0, kI=0, kF=0, noise_amplitude=1)
plot_result = plotSys(bsub_closed_sys, forced_input=[SETPOINT], times=BSUB_TIMES, 
                      is_plot=True, output_labels=["Gp"], ylim=[0, 30])

# %% [markdown]
# ## Tuning

# %% [markdown]
# Make any further adjustments to your design using the testbed to evaluate the results. If none adjustments are required, indicate why this is the case.

# %% [markdown]
# In order to get to this final design a fair amount of tuning was required. Most of this I did with the optimization functions provided, changing parameters like kmax, which I attempted to keep as low as possible while still maintaining a quick response. I also ran several iterations of the optimization with various combinations of the controller parts and parameters. I attempted with and without the filter, with only proportional control, and with only proportional and integral control. Overall I found that noise reduction was absolutely necessary to have any kind of control of the desired output and that integral control didnt seem to have a very large affect on the close loop system.

# %%
# System with design parameters
kP = BSUB_DESIGN_RESULT.params["kP"].value
kI = BSUB_DESIGN_RESULT.params["kI"].value
kD = BSUB_DESIGN_RESULT.params["kD"].value
if "kF" in BSUB_DESIGN_RESULT.params.keys():
    kF = BSUB_DESIGN_RESULT.params["kF"].value
else:
    kF = 1000
bsub_closed_sys = makeClosedLoopSystem(bsubtilus_CTLSB, kP=kP, kI=kI, kD=kD, kF=kF,
                                      noise_amplitude=1)
plot_result = plotSys(bsub_closed_sys, forced_input=[SETPOINT], times=BSUB_TIMES, 
                      is_plot=True, output_labels=["Gp", "control_input"])
plot_result = plotSys(bsub_closed_sys, forced_input=[SETPOINT], times=BSUB_TIMES, 
                      is_plot=True, output_labels=["Gp", "control_input"],ylim=[0,25])

# %% [markdown]
# # Step 5. Discussion (15 pts)

# %% [markdown]
# 1. How does the operating range of the OLS in the stepbed compare with the operating range you used in Step 2?
# The operating range of input in the test bed was within the operating range defined in Step 2. However, there is a short period of time in the begining in which the control point is negative which was not previously defined and would required a method by which to remove ammonia from the system rapidly. Otherwise, the operating range primarily is between 1 and 5 mmol of ammonia which is very reasonable to achieve out setpoint of 10mmol glutamate.
#
# 2. How well are control objectives achieved?
# The control objectives were not sufficiently achieved even after a fair amount of optimization and tuning. Even in the control closed loop system, there are still a fair amount of oscilations. However, the amplitude of the oscillation reduced from about 25 to 3 which is a significant improvement. These oscillations are around the set point of 10 and this somewhat steady state is reached very quickly in the simulation indicating a good settling time.
#
# 3. What value did you get from doing control design?
# This exercise was a great way to put everything from the course all together in a signle notebook. I think without trying it myself from start to finish I would have been oblivious to a lot of the common issues that are possible when trying to do this design. Having these issues come up first hand and having to trouble shoot them for this project really made it necessary to reflect on the theory to come up with logical solutions which strengthened my understanding of both the theory and the application. I really enjoyed this final homework and thought it brought all of the parts of the course together very nicely.
