# %% [markdown]
# #PYTHON REVIEW

# %%
This notebook reviews essential python data structures and control flows, including the numpy and pandas packages.
The notebook also reviews how to run and modify a Tellurium simulation.

# %%
try:
    import controlSBML as ctl
except:
    # !pip install controlSBML
    import controlSBML as ctl

import numpy as np
import pandas as pd
import matplotlib as plt

# %%
# Created data that will be used later
CTLSB = ctl.ControlSBML("https://www.ebi.ac.uk/biomodels/model/download/BIOMD0000000823.2?filename=Varusai2018.xml")
RR = CTLSB.roadrunner
DATA = RR.simulate()
DF = CTLSB.jacobian_df
MAT = DF.values

# %% [markdown]
# Additions
# 1. Rules for writing reproducible SW

# %% [markdown]
# # The Colab Environment
# * Setup
# * Code and text cells
# * Namespace persistence
# * Formulas in text cells

# %% [markdown]
# # Elemental Types

# %% [markdown]
# * str, float, int
# * list
# * dict

# %% [markdown]
# # Numpy Arrays and linear algebra

# %% [markdown]
# * Create arrays
# * Shaping arrays
# * Indexing and slicing
# * ``linspace``
# * Array arithmetic
# * Inverse of a matrix
# * Eigenvalues, eigenvectors
# * Singular value decomposition

# %%
eigen_vals, eigen_mat = np.linalg.eig(MAT)
eigen_vals
# Out:
# array([-5.96385198e+00+0.00000000e+00j, -5.69362481e-01+0.00000000e+00j,
#        -4.72123271e-01+0.00000000e+00j, -4.03532170e-01+0.00000000e+00j,
#        -1.77702499e-01+0.00000000e+00j, -5.82127872e-02+0.00000000e+00j,
#        -3.07583679e-02+0.00000000e+00j, -2.00668767e-02+6.89465384e-04j,
#        -2.00668767e-02-6.89465384e-04j, -2.04869604e-17+3.08724147e-17j,
#        -2.04869604e-17-3.08724147e-17j,  3.54994535e-17+0.00000000e+00j,
#         2.13417223e-17+0.00000000e+00j, -3.44116731e-17+0.00000000e+00j,
#        -1.83083562e-18+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j])

# %% [markdown]
# # Plotting
# * line and scatter plots
# * changing the attributes of plots

# %% [markdown]
# # Pandas Series and DataFrames

# %% [markdown]
# * Philosophy
# * Series: values, index, combining series, sorting index, indexing with ``loc``, convert to array, read and write
# * DataFrame: Creating with columns and values, repeat of Series

# %% [markdown]
# # Python flow of control

# %% [markdown]
# * ``if``, ``elif``, ``else``
# * ``for``
# * ``def`` (functions) and requirements for writing functions

# %% [markdown]
# # Tellurium

# %% [markdown]
# ## Running Tellurium

# %% [markdown]
# ## Modifying Tellurium Constants

# %% [markdown]
# ## Getting Species Rates

# %% [markdown]
# # controlSBML
