# %% [markdown]
# # System Identification

# %% [markdown]
# System identification is the process of finding a transfer function that predicts outputs
# that are close to those predicted by experimental data. These data
# may be obtained from actual experiments for from a detailed nonlinear model.
# System identification involves: iteratively choosing the size of the numerator and denominator polynomial
# of the transfer function,
# estimating the parameters of the transfer function, and evaluating the quality of the fit to
# the predictions of the transfer function.

# %% [markdown]
# ## Preliminaries

# %%
import controlSBML as ctl

import control
import lmfit
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tellurium as te
ctl.__version__
# Out:
# '1.0.11'

# %% [markdown]
# ## Models

# %% [markdown]
# ### LINEAR_MODEL

# %%
LINEAR_MODEL = """
J1: S1 -> S2; k1*S1
J2: S2 -> S3; k2*S2
J3: S3 -> ; k3*S3
S1 = 10; S2 = 0; S3 = 0

k1 = 1
k2 = 1
k3 = 1
"""
rr = te.loada(LINEAR_MODEL)
rr.simulate()
rr.plot(figsize=(3,3))

# %%
LINEAR_CTLSB = ctl.ControlSBML(LINEAR_MODEL, input_names=["S1"], output_names=["S3"])

# %% [markdown]
# ### WOLF_MODEL

# %%
WOLF_URL = "https://www.ebi.ac.uk/biomodels/model/download/BIOMD0000000206.2?filename=BIOMD0000000206_url.xml"
rr = te.loadSBMLModel(WOLF_URL)
WOLF_MODEL = rr.getAntimony()
WOLF_CTLSB = ctl.ControlSBML(WOLF_MODEL, input_names=["at_"], output_names=["s5"])
print(WOLF_MODEL)
# Out:
# // Created by libAntimony v2.13.2
# model *Wolf2000_Glycolytic_Oscillations()
#
#   // Compartments and Species:
#   compartment compartment_;
#   species s1 in compartment_, at_ in compartment_, s2 in compartment_, s3 in compartment_;
#   species na in compartment_, s4 in compartment_, s5 in compartment_, s6 in compartment_;
#   species s6o in compartment_;
#
#   // Reactions:
#   v1: s1 + 2 at_ -> s2; compartment_*k1*s1*at_/(1 + (at_/ki)^n);
#   v2: s2 -> 2 s3; compartment_*k2*s2;
#   v3: s3 + na -> s4 + at_; compartment_*((k31*k32*s3*na*(atot - at_) - k33*k34*s4*at_*(ntot - na))/(k33*(ntot - na) + k32*(atot - at_)));
#   v4: s4 -> s5 + at_; compartment_*k4*s4*(atot - at_);
#   v5: s5 -> s6; compartment_*k5*s5;
#   v7: at_ -> ; compartment_*k7*at_;
#   v8: s3 -> na; compartment_*k8*s3*(ntot - na);
#   v9: s6o -> ; compartment_*k9*s6o;
#   v10: s6 -> 0.1 s6o; compartment_*k10*(s6 - s6o);
#   v6: s6 -> na; compartment_*k6*s6*(ntot - na);
#   v0:  -> s1; compartment_*k0;
#
#   // Species initializations:
#   s1 = 1;
#   at_ = 2;
#   s2 = 5;
#   s3 = 0.6;
#   na = 0.6;
#   s4 = 0.7;
#   s5 = 8;
#   s6 = 0.08;
#   s6o = 0.02;
#
#   // Compartment initializations:
#   compartment_ = 1;
#
#   // Variable initializations:
#   k0 = 50;
#   k0 has mM_min_1;
#   k1 = 550;
#   k1 has mM_1_min_1;
#   k2 = 9.8;
#   k2 has min_1;
#   k31 = 323.8;
#   k31 has mM_1_min_1;
#   k33 = 57823.1;
#   k33 has mM_1_min_1;
#   k32 = 76411.1;
#   k32 has mM_1_min_1;
#   k34 = 23.7;
#   k34 has mM_1_min_1;
#   k4 = 80;
#   k4 has mM_1_min_1;
#   k5 = 9.7;
#   k5 has min_1;
#   k6 = 2000;
#   k6 has mM_1_min_1;
#   k7 = 28;
#   k7 has min_1;
#   k8 = 85.7;
#   k8 has mM_1_min_1;
#   k9 = 80;
#   k9 has min_1;
#   k10 = 375;
#   k10 has min_1;
#   atot = 4;
#   atot has mM;
#   ntot = 1;
#   ntot has mM;
#   n = 4;
#   n has dimensionless;
#   ki = 1;
#   ki has mM;
#
#   // Other declarations:
#   const compartment_, k0, k1, k2, k31, k33, k32, k34, k4, k5, k6, k7, k8;
#   const k9, k10, atot, ntot, n, ki;
#
#   // Unit definitions:
#   unit substance = 1e-3 mole;
#   unit time_unit = 60 second;
#   unit mM = 1e-3 mole / litre;
#   unit mM_min_1 = 1e-3 mole / (litre * 60 second);
#   unit min_1 = 1 / 60 second;
#   unit mM_1_min_1 = litre / (1e-3 mole * 60 second);
#
#   // Display Names:
#   substance is "milli mole";
#   time_unit is "min";
#   compartment_ is "compartment";
#   s1 is "Glucose";
#   at_ is "ATP";
#   s2 is "F16P";
#   s3 is "Triose_Gly3Phos_DHAP";
#   na is "NAD";
#   s4 is "3PG";
#   s5 is "Pyruvate";
#   s6 is "Acetaldehyde";
#   s6o is "extracellular acetaldehyde";
#
#   // CV terms:
#   s1 identity "http://identifiers.org/obo.chebi/CHEBI:17234",
#               "http://identifiers.org/kegg.compound/C00293"
#   at_ identity "http://identifiers.org/obo.chebi/CHEBI:15422",
#                "http://identifiers.org/kegg.compound/C00002"
#   s2 identity "http://identifiers.org/obo.chebi/CHEBI:16905",
#               "http://identifiers.org/kegg.compound/C05378"
#   s3 part "http://identifiers.org/obo.chebi/CHEBI:16108",
#           "http://identifiers.org/obo.chebi/CHEBI:29052",
#           "http://identifiers.org/kegg.compound/C00111",
#           "http://identifiers.org/kegg.compound/C00118"
#   na identity "http://identifiers.org/obo.chebi/CHEBI:15846",
#               "http://identifiers.org/kegg.compound/C00003"
#   s4 identity "http://identifiers.org/obo.chebi/CHEBI:17794",
#               "http://identifiers.org/kegg.compound/C00197"
#   s5 identity "http://identifiers.org/kegg.compound/C00022",
#               "http://identifiers.org/chebi/CHEBI:32816"
#   s5 identity "http://identifiers.org/obo.chebi/CHEBI:15361"
#   s6 identity "http://identifiers.org/obo.chebi/CHEBI:15343",
#               "http://identifiers.org/kegg.compound/C00084"
#   s6o identity "http://identifiers.org/obo.chebi/CHEBI:15343",
#                "http://identifiers.org/kegg.compound/C00084"
#   v1 part "http://identifiers.org/kegg.reaction/R00756",
#           "http://identifiers.org/kegg.reaction/R00299"
#   v1 part "http://identifiers.org/ec-code/2.7.1.11",
#           "http://identifiers.org/ec-code/5.3.1.9"
#   v2 identity "http://identifiers.org/ec-code/4.1.2.13",
#               "http://identifiers.org/kegg.reaction/R01070"
#   v3 part "http://identifiers.org/ec-code/2.7.2.3",
#           "http://identifiers.org/ec-code/1.2.1.12"
#   v4 part "http://identifiers.org/kegg.reaction/R00658",
#           "http://identifiers.org/kegg.reaction/R00200"
#   v4 part "http://identifiers.org/ec-code/2.7.1.40"
#   v5 hypernym "http://identifiers.org/ec-code/4.1.1.1",
#               "http://identifiers.org/kegg.reaction/R00224"
#   v7 hypernym "http://identifiers.org/obo.go/GO:0006754"
#   v8 part "http://identifiers.org/kegg.reaction/R05679"
#   v9 hypernym "http://identifiers.org/obo.go/GO:0046187"
#   v6 hypernym "http://identifiers.org/ec-code/1.1.1.71",
#               "http://identifiers.org/kegg.reaction/R00754"
#   v0 hypernym "http://identifiers.org/obo.go/GO:0046323"
# end
#
# Wolf2000_Glycolytic_Oscillations is "Wolf2000_Glycolytic_Oscillations"
#
# Wolf2000_Glycolytic_Oscillations model_entity_is "http://identifiers.org/biomodels.db/MODEL3352181362"
# Wolf2000_Glycolytic_Oscillations model_entity_is "http://identifiers.org/biomodels.db/BIOMD0000000206"
# Wolf2000_Glycolytic_Oscillations description "http://identifiers.org/pubmed/10692304"
# Wolf2000_Glycolytic_Oscillations taxon "http://identifiers.org/taxonomy/4932"
# Wolf2000_Glycolytic_Oscillations hypernym "http://identifiers.org/obo.go/GO:0006096"
# Wolf2000_Glycolytic_Oscillations identity "http://identifiers.org/kegg.pathway/sce00010"

# %%
rr = te.loada(WOLF_MODEL)
rr.simulate()
rr.plot()

# %% [markdown]
# ### MTOR_MODEL

# %%
MTOR_URL = "https://www.ebi.ac.uk/biomodels/model/download/BIOMD0000000823.2?filename=Varusai2018.xml"
rr = te.loadSBMLModel(MTOR_URL)
MTOR_MODEL = rr.getAntimony()
MTOR_CTLSB = ctl.ControlSBML(MTOR_MODEL, input_names=["pIR"], output_names=["mTORC1_DEPTOR"])
print(MTOR_MODEL)
# Out:
# // Created by libAntimony v2.13.2
# function Constant_flux__irreversible(v)
#   v;
# end
#
# Constant_flux__irreversible is "Constant flux (irreversible)"
#
# function Henri_Michaelis_Menten__irreversible(substrate, Km, V)
#   V*substrate/(Km + substrate);
# end
#
# Henri_Michaelis_Menten__irreversible is "Henri-Michaelis-Menten (irreversible)"
#
# function HMM_Mod(V, s, m, Km)
#   V*s*m/(Km + s);
# end
#
# HMM_Mod is "HMM_Mod"
#
# function Function_for_v11(k11ca, pmTORC1, DEPTOR, Km11a, pDEPTOR, k11cb, pmTORC2, Km11b)
#   k11ca*pmTORC1*DEPTOR/(Km11a + pDEPTOR) + k11cb*pmTORC2*DEPTOR/(Km11b + DEPTOR);
# end
#
# Function_for_v11 is "Function_for_v11"
#
# function Function_for_v5(k5ca, pIRS, Akt, Km5a, k5cb, pmTORC2, Km5b)
#   k5ca*pIRS*Akt/(Km5a + Akt) + k5cb*pmTORC2*Akt/(Km5b + Akt);
# end
#
# Function_for_v5 is "Function_for_v5"
#
#
# model *Varusai2018___Dynamic_modelling_of_the_mTOR_signalling_network_reveals_complex_emergent_behaviours_conferred_by_DEPTOR()
#
#   // Compartments and Species:
#   compartment compartment_;
#   species IR in compartment_, pIR in compartment_, IRS in compartment_, pIRS in compartment_;
#   species iIRS in compartment_, Akt in compartment_, pAkt in compartment_;
#   species mTORC1 in compartment_, pmTORC1 in compartment_, mTORC2 in compartment_;
#   species pmTORC2 in compartment_, imTORC2 in compartment_, mTORC1_DEPTOR in compartment_;
#   species mTORC2_DEPTOR in compartment_, DEPTOR in compartment_, pDEPTOR in compartment_;
#
#   // Reactions:
#   v1: IR => pIR; compartment_*Henri_Michaelis_Menten__irreversible(IR, Km1, V1);
#   v2: pIR => IR; compartment_*Henri_Michaelis_Menten__irreversible(pIR, Km2, V2);
#   v3: IRS => pIRS; compartment_*HMM_Mod(k3c, IRS, pIR, Km3);
#   v4: pIRS => IRS; compartment_*Henri_Michaelis_Menten__irreversible(pIRS, Km4, V4);
#   v5: Akt => pAkt; compartment_*Function_for_v5(k5ca, pIRS, Akt, Km5a, k5cb, pmTORC2, Km5b);
#   v6: pAkt => Akt; compartment_*Henri_Michaelis_Menten__irreversible(pAkt, Km6, V6);
#   v7: mTORC1 => pmTORC1; compartment_*HMM_Mod(k7c, mTORC1, pAkt, Km7);
#   v8: pmTORC1 => mTORC1; compartment_*Henri_Michaelis_Menten__irreversible(pmTORC1, Km8, V8);
#   v9: mTORC2 => pmTORC2; compartment_*HMM_Mod(k9c, mTORC2, pIR, Km9);
#   v10: pmTORC2 => mTORC2; compartment_*Henri_Michaelis_Menten__irreversible(pmTORC2, Km10, V10);
#   v11: DEPTOR => pDEPTOR; compartment_*Function_for_v11(k11ca, pmTORC1, DEPTOR, Km11a, pDEPTOR, k11cb, pmTORC2, Km11b);
#   v12: pDEPTOR => DEPTOR; compartment_*Henri_Michaelis_Menten__irreversible(pDEPTOR, Km12, V12);
#   v13: mTORC1 + DEPTOR -> mTORC1_DEPTOR; compartment_*(k13f*mTORC1*DEPTOR - k13r*mTORC1_DEPTOR);
#   v14: mTORC2 + DEPTOR -> mTORC2_DEPTOR; compartment_*(k14f*mTORC2*DEPTOR - k14r*mTORC2_DEPTOR);
#   v15: IRS => iIRS; compartment_*HMM_Mod(k15c, IRS, pmTORC1, Km15);
#   v16: iIRS => IRS; compartment_*Henri_Michaelis_Menten__irreversible(iIRS, Km16, V16);
#   v17:  => DEPTOR; compartment_*Constant_flux__irreversible(ks17);
#   v18: pDEPTOR => ; compartment_*kd18*pDEPTOR;
#
#   // Species initializations:
#   IR = 50;
#   pIR = 0;
#   IRS = 100;
#   pIRS = 0;
#   iIRS = 0;
#   Akt = 100;
#   pAkt = 0;
#   mTORC1 = 250;
#   pmTORC1 = 0;
#   mTORC2 = 200;
#   pmTORC2 = 0;
#   imTORC2 = 0;
#   mTORC1_DEPTOR = 0;
#   mTORC2_DEPTOR = 0;
#   DEPTOR = 350;
#   pDEPTOR = 0;
#
#   // Compartment initializations:
#   compartment_ = 1;
#
#   // Variable initializations:
#   V1 = 1;
#   Km1 = 95;
#   V2 = 1;
#   Km2 = 35;
#   k3c = 0.1;
#   Km3 = 50;
#   V4 = 1;
#   Km4 = 50;
#   k5ca = 0.05;
#   Km5a = 7;
#   k5cb = 1.5;
#   Km5b = 4;
#   V6 = 2;
#   Km6 = 34;
#   k7c = 0.1;
#   Km7 = 2;
#   V8 = 6;
#   Km8 = 1;
#   k9c = 0.3;
#   Km9 = 160;
#   V10 = 3;
#   Km10 = 7;
#   k11ca = 0.1;
#   Km11a = 120;
#   k11cb = 0.13;
#   Km11b = 11;
#   V12 = 4;
#   Km12 = 7;
#   k13f = 0.001;
#   k13r = 0.006;
#   k14f = 0.007;
#   k14r = 0.006;
#   k15c = 0.1;
#   Km15 = 50;
#   V16 = 1;
#   Km16 = 50;
#   ks17 = 0;
#   kd18 = 0;
#
#   // Other declarations:
#   const compartment_, V1, Km1, V2, Km2, k3c, Km3, V4, Km4, k5ca, Km5a, k5cb;
#   const Km5b, V6, Km6, k7c, Km7, V8, Km8, k9c, Km9, V10, Km10, k11ca, Km11a;
#   const k11cb, Km11b, V12, Km12, k13f, k13r, k14f, k14r, k15c, Km15, V16;
#   const Km16, ks17, kd18;
#
#   // Unit definitions:
#   unit volume = 1e-3 litre;
#   unit substance = 1e-3 mole;
#
#   // Display Names:
#   compartment_ is "compartment";
#
#   // CV terms:
#   compartment_ hypernym "http://identifiers.org/ncit/C48694"
#   IR identity "http://identifiers.org/pr/PR:000009064"
#   pIR hypernym "http://identifiers.org/pr/PR:000009064"
#   IRS identity "http://identifiers.org/ncit/C28474"
#   pIRS hypernym "http://identifiers.org/ncit/C28474"
#   iIRS hypernym "http://identifiers.org/ncit/C28474"
#   Akt identity "http://identifiers.org/pr/PR:000029189"
#   pAkt hypernym "http://identifiers.org/pr/PR:000029189"
#   mTORC1 hypernym "http://identifiers.org/ncit/C96314"
#   pmTORC1 hypernym "http://identifiers.org/ncit/C96314"
#   mTORC2 identity "http://identifiers.org/ncit/C96315"
#   pmTORC2 hypernym "http://identifiers.org/ncit/C96315"
#   imTORC2 hypernym "http://identifiers.org/ncit/C96315"
#   mTORC1_DEPTOR part "http://identifiers.org/ncit/C96314"
#   mTORC1_DEPTOR part "http://identifiers.org/ncit/C101595"
#   mTORC2_DEPTOR part "http://identifiers.org/ncit/C101595"
#   mTORC2_DEPTOR part "http://identifiers.org/ncit/mTORC2"
#   DEPTOR identity "http://identifiers.org/ncit/C101595"
#   pDEPTOR hypernym "http://identifiers.org/ncit/C101595"
#   v1 hypernym "http://identifiers.org/go/GO:0016310"
#   v2 hypernym "http://identifiers.org/go/GO:0016311"
#   v3 hypernym "http://identifiers.org/go/GO:0016310"
#   v4 hypernym "http://identifiers.org/go/GO:0016311"
#   v5 hypernym "http://identifiers.org/go/GO:0016310"
#   v6 hypernym "http://identifiers.org/go/GO:0016311"
#   v7 hypernym "http://identifiers.org/go/GO:0016310"
#   v8 hypernym "http://identifiers.org/go/GO:0016311"
#   v9 hypernym "http://identifiers.org/go/GO:0016310"
#   v10 hypernym "http://identifiers.org/go/GO:0016311"
#   v11 hypernym "http://identifiers.org/go/GO:0016310"
#   v12 hypernym "http://identifiers.org/go/GO:0016311"
#   v13 hypernym "http://identifiers.org/ncit/C18469"
#   v14 hypernym "http://identifiers.org/ncit/C18469"
#   v15 hypernym "http://identifiers.org/ncit/C16983"
#   v15 hypernym "http://identifiers.org/sbo/SBO:0000169"
#   v16 hypernym "http://identifiers.org/ncit/C21018"
#   v17 hypernym "http://identifiers.org/ncit/C80450"
#   v18 hypernym "http://identifiers.org/ncit/C61559"
# end
#
# Varusai2018___Dynamic_modelling_of_the_mTOR_signalling_network_reveals_complex_emergent_behaviours_conferred_by_DEPTOR is "Varusai2018 - Dynamic modelling of the mTOR signalling network reveals complex emergent behaviours conferred by DEPTOR"
#
# Varusai2018___Dynamic_modelling_of_the_mTOR_signalling_network_reveals_complex_emergent_behaviours_conferred_by_DEPTOR description "http://identifiers.org/pubmed/29330362"
# Varusai2018___Dynamic_modelling_of_the_mTOR_signalling_network_reveals_complex_emergent_behaviours_conferred_by_DEPTOR model_entity_is "http://identifiers.org/biomodels.db/MODEL1909250003",
#                                                                                                                                        "http://identifiers.org/biomodels.db/BIOMD0000000823"
# Varusai2018___Dynamic_modelling_of_the_mTOR_signalling_network_reveals_complex_emergent_behaviours_conferred_by_DEPTOR property "http://identifiers.org/mamo/MAMO_0000046"
# Varusai2018___Dynamic_modelling_of_the_mTOR_signalling_network_reveals_complex_emergent_behaviours_conferred_by_DEPTOR property "http://identifiers.org/pw/PW:0000180"
# Varusai2018___Dynamic_modelling_of_the_mTOR_signalling_network_reveals_complex_emergent_behaviours_conferred_by_DEPTOR property "http://identifiers.org/ncit/C101595"
# Varusai2018___Dynamic_modelling_of_the_mTOR_signalling_network_reveals_complex_emergent_behaviours_conferred_by_DEPTOR taxon "http://identifiers.org/taxonomy/9606"

# %%
rr = te.loada(MTOR_MODEL)
rr.simulate()
rr.plot()

# %% [markdown]
# # Linear model transfer function

# %% [markdown]
# In this section, we use LINEAR_MODEL to illustrate system identification.
# The work can be simplied by making use of the ``SISOTransferFunctionBuilder``
# object in ``ControlSBML``.

# %% [markdown]
# ## Step 1. Construct the ``SISOTransferFunctionBuilder``

# %% [markdown]
# ``SISOTransferFunctonBuilder`` is a ``controlSBML`` object that faciliates system identification
# of transfer functions for SBML models.

# %%
LINEAR_BUILDER = LINEAR_CTLSB.makeSISOTransferFunctionBuilder()
LINEAR_BUILDER.input_name, LINEAR_BUILDER.output_name
# Out:
# ('S1', 'S3')

# %% [markdown]
# ## Step 2. Determine the operating region

# %% [markdown]
# The operating region is the range of control inputs that should handled by the controller.
# We want to see how responsive the system is to the possible outputs from the controller.
# We assess the operating region by using a *staircase input*.
# This is a sequence of steps of the same height that have a duration that is sufficiently
# long so that the system stabilizes.

# %%
STAIRCASE = ctl.Staircase(initial_value=2, final_value=10, num_step=5)

# %%
response_ts = LINEAR_BUILDER.makeStaircaseResponse(end_time=100, staircase=STAIRCASE)
response_ts
# Out:
#                    S3  S1_staircase
# miliseconds
# 0            0.000000           2.0
# 100          0.045551           2.0
# 200          0.166018           2.0
# 300          0.340564           2.0
# 400          0.552061           2.0
# ...               ...           ...
# 99600        9.995577          10.0
# 99700        9.995058          10.0
# 99800        9.994765          10.0
# 99900        9.994759          10.0
# 100000       9.995107          10.0
#
# [1001 rows x 2 columns]

# %%
LINEAR_BUILDER.plotStaircaseResponse(response_ts, figsize=(3,3), legend_crd=(0.5, 1), start_time=25, end_time=100)

# %% [markdown]
# ## Step 3. Find the transfer function

# %% [markdown]
# To fit a transfer function, we must specify the number of terms in the
# numerator and denominator polynomials for the transfer function.

# %%
fitter_result = LINEAR_BUILDER.fitTransferFunction(num_numerator=2, num_denominator=3, staircase=STAIRCASE, start_time=0, end_time=50)
ctl.plotOneTS(fitter_result.time_series, figsize=(3,3), legend_crd=(2,1))

# %%
# Here is the transfer function
fitter_result.transfer_function
# Out:
# TransferFunction(array([0.06044039, 0.03333355]), array([0.15126051, 0.03626249, 0.03681415]))

# %%
# The number of function evaluations and the reduced ChiSq are larger because of the initial conditions.
fitter_result.nfev, fitter_result.redchi
# Out:
# (129, 0.17081071163053918)

# %%
# Do the analysis starting after the initial conditions.
fitter_result = LINEAR_BUILDER.fitTransferFunction(3, 3, staircase=STAIRCASE,
                                                   start_time=20, end_time=50)
ctl.plotOneTS(fitter_result.time_series, figsize=(3,3), legend_crd=(2,1))

# %%
# The number of function evaluations and the reduced ChiSq are smaller now.
# Also, the fit is much better.
fitter_result.nfev, fitter_result.redchi
# Out:
# (142, 0.0002635745938439853)

# %% [markdown]
# This plot displays values of ``S3`` in response to values of ``S1``.
# We see that the output closely follows the input, and that there is a response over
# the entire range of input.

# %%
# The transfer function is the same, but it fits better because we eliminated initial conditions.
fitter_result.transfer_function
# Out:
# TransferFunction(array([ 0.03217538, -0.19511826,  0.55907225]), array([1.26350949, 1.47073585, 0.56084681]))

# %%
tf = fitter_result.transfer_function
tf.dcgain()
# Out:
# 0.9968359333216481

# %%
tf.poles()
# Out:
# array([-0.58200427+0.32427025j, -0.58200427-0.32427025j])

# %%
fitter_result.nfev
# Out:
# 142

# %% [markdown]
# ## Step 4. Analyze the fit result

# %% [markdown]
# ``fitter_result`` has many useful properties.
# * ``minimizer_result`` contains detailed information about the results of the optimization
# * ``nfev`` is the number of different transfer functions that were evaluated to find the fit
# * ``parameters`` contains the parameter values
# * ``redchi`` is the reduced ChiSq for the fit
# * ``stderr`` contains the standard deviations of the parameter values
# * ``time_series`` is a ``Timeseries`` object with the input, nonlinear simulated output, and predicted value of the output
# * ``transfer_function`` is the fitted transfer function

# %%
fitter_result.parameters
# Out:
# Parameters([('n0', <Parameter 'n0', value=0.032175375330849576 +/- 20.2, bounds=[-10:10]>), ('n1', <Parameter 'n1', value=-0.1951182551765065 +/- 123, bounds=[-10:10]>), ('n2', <Parameter 'n2', value=0.5590722532384973 +/- 352, bounds=[-10:10]>), ('d0', <Parameter 'd0', value=1.263509493888229 +/- 794, bounds=[-10:10]>), ('d1', <Parameter 'd1', value=1.4707358482918842 +/- 925, bounds=[-10:10]>), ('d2', <Parameter 'd2', value=0.5608468099414932 +/- 353, bounds=[-10:10]>)])

# %%
fitter_result.transfer_function
# Out:
# TransferFunction(array([ 0.03217538, -0.19511826,  0.55907225]), array([1.26350949, 1.47073585, 0.56084681]))

# %%
print(fitter_result.transfer_function)
ctl.plotOneTS(fitter_result.time_series, figsize=(3,3), legend_crd=(2, 1))
# Out:
# 0.03218 s^2 - 0.1951 s + 0.5591
# -------------------------------
#  1.264 s^2 + 1.471 s + 0.5608

# %% [markdown]
# #  Wolf Transfer Function

# %%
WOLF_BUILDER = WOLF_CTLSB.makeSISOTransferFunctionBuilder(is_fixed_input_species=True)
WOLF_BUILDER.input_name, WOLF_BUILDER.output_name
# Out:
# ('at_', 's5')

# %%
WOLF_STAIRCASE = ctl.Staircase(initial_value=0, final_value=0.001, num_step=5)
response_ts = WOLF_BUILDER.makeStaircaseResponse(staircase=WOLF_STAIRCASE, figsize=(1,2), legend_crd=(0.5, 1), end_time=10)

# %%
WOLF_BUILDER.plotStaircaseResponse(response_ts, figsize=(3,3), legend_crd=(0.5, 1), ylim=[0, 15])

# %%
fitter_result = WOLF_BUILDER.fitTransferFunction(num_numerator=1, num_denominator=2, staircase=WOLF_STAIRCASE, end_time=100)
print(fitter_result.transfer_function)
ctl.plotOneTS(fitter_result.time_series, figsize=(3,3), legend_crd=(2, 1))
# Out:
# /Users/jlheller/home/Technical/repos/controlSBML/src/controlSBML/msgs.py:13: UserWarning:
#
#
#
# ***Warning*** Could not find a steady state. Using current state.
#          3.968
# -----------------------
# 1.987e-06 s + 0.0003128
# /Users/jlheller/home/Technical/repos/controlSBML/src/controlSBML/msgs.py:13: UserWarning:
#
#
#
# ***Warning*** Possible numerical instability: max abs residual is 12.703439

# %%
fitter_result.time_series
# Out:
#                    s5  predicted  at__staircase
# miliseconds
# 0            8.000000   0.000000          0.000
# 100          6.792599   0.000000          0.000
# 200          4.013953   0.000000          0.000
# 300          2.068208   0.000000          0.000
# 400          0.990029   0.000000          0.000
# ...               ...        ...            ...
# 99600        8.415993  12.687376          0.001
# 99700        8.415986  12.687376          0.001
# 99800        8.415968  12.687376          0.001
# 99900        8.415956  12.687376          0.001
# 100000       8.415943  12.687376          0.001
#
# [1001 rows x 3 columns]

# %%
fitter_result.transfer_function.dcgain()
# Out:
# 12687.375669317124

# %% [markdown]
# Is this model sufficiently accurate to do control design?
#
# The key consideration here is accuracy of DC Gain. How do the step increases in input relate to the magnitude of the increase in output?

# %% [markdown]
# # mTOR transfer function

# %%
MTOR_BUILDER = MTOR_CTLSB.makeSISOTransferFunctionBuilder()
MTOR_STAIRCASE = ctl.Staircase(initial_value=0, final_value=1, num_step=5)
response_ts = MTOR_BUILDER.makeStaircaseResponse(staircase=MTOR_STAIRCASE, end_time=2000)

# %%
MTOR_BUILDER.plotStaircaseResponse(response_ts,  figsize=(3,3), legend_crd=(2, 1))

# %%
fitter_result = MTOR_BUILDER.fitTransferFunction(num_numerator=2, num_denominator=3, staircase=MTOR_STAIRCASE, start_time=0, end_time=30)
MTOR_BUILDER.plotFitTransferFunction(fitter_result)
# Out:
# /Users/jlheller/home/Technical/repos/controlSBML/src/controlSBML/msgs.py:13: UserWarning:
#
#
#
# ***Warning*** Could not find a steady state. Using current state.
#
# /Users/jlheller/home/Technical/repos/controlSBML/src/controlSBML/msgs.py:13: UserWarning:
#
#
#
# ***Warning*** Possible numerical instability: max abs residual is 102.916880

# %% [markdown]
# There does not seem to be a relationship between the step input and the output.

# %% [markdown]
# # Metformin in Mice (MODEL2206230001)

# %% [markdown]
# This is a whole-body model representing the pharmacokinetics of metformin in the mouse body. The model is in the form of ordinary differential equations and describes metformin concentration in 20 compartments. The model consists of 20 compartments (“Compartments” in COPASI model) describing various tissues or tissue sub-compartments and body fluids of metformin action (venous and arterial plasma, intestine, kidney, heart, fat, muscle, brain, lungs, stomach, liver, portal vein, remainder urine and feces).

# %%
url = "https://www.ebi.ac.uk/biomodels/model/download/BIOMD0000001039.5?filename=Zake2021_Metformin%2BMice%2BIV.xml"
ctlsb = ctl.ControlSBML(url, input_names=["mHeart"], output_names=["mMuscle"])
print(ctlsb.antimony)
METFORMIN_BUILDER = ctlsb.makeSISOTransferFunctionBuilder(is_fixed_input_species=True)
# Out:
# // Created by libAntimony v2.13.2
# function Henri_Michaelis_Menten__irreversible(substrate, Km, V)
#   V*substrate/(Km + substrate);
# end
#
# Henri_Michaelis_Menten__irreversible is "Henri-Michaelis-Menten (irreversible)"
#
# function Glomerular(S, Flow)
#   S*Flow;
# end
#
# Glomerular is "Glomerular"
#
# function Flow(Q, S)
#   Q*S;
# end
#
# Flow is "Flow"
#
# function Flow_from_organ(Q, S, Ktp)
#   Q*S/Ktp;
# end
#
# Flow_from_organ is "Flow from organ"
#
#
# model *Zake2021___PBPK_model_of_metformin_in_mice__single_dose_intavenous()
#
#   // Compartments and Species:
#   compartment IntestineLumen, Liver, KidneyPlasma, Remainder, PlasmaVenous;
#   compartment Urine, Feces, Heart, Muscle, Brain, Adipose, PlasmaArterial;
#   compartment Lung, PortalVein, Stomach, IntestineEnterocytes, KidneyTissue;
#   compartment IntestineVascular, StomachLumen, KidneyTubular;
#   substanceOnly species mLiver in Liver, mKidneyPlasma in KidneyPlasma, mRemainder in Remainder;
#   substanceOnly species mPlasmaVenous in PlasmaVenous, mHeart in Heart, mMuscle in Muscle;
#   substanceOnly species mAdipose in Adipose, mBrain in Brain, mFeces in Feces;
#   substanceOnly species mUrine in Urine, mIntestineLumen in IntestineLumen;
#   substanceOnly species mPlasmaArterial in PlasmaArterial, mLung in Lung;
#   substanceOnly species mPortalVein in PortalVein, mStomach in Stomach, mIntestineEnterocytes in IntestineEnterocytes;
#   substanceOnly species mKidneyTissue in KidneyTissue, mIntestineVascular in IntestineVascular;
#   substanceOnly species mStomachLumen in StomachLumen, mKidneyTubular in KidneyTubular;
#
#   // Assignment Rules:
#   Liver := ModelValue_1*0.0549;
#   KidneyPlasma := ModelValue_1*0.0056;
#   Remainder := ModelValue_1*0.3585;
#   PlasmaVenous := ModelValue_1*0.0375;
#   Heart := ModelValue_1*0.005;
#   Muscle := ModelValue_1*0.384;
#   Brain := ModelValue_1*0.0165;
#   Adipose := ModelValue_1*0.07;
#   PlasmaArterial := ModelValue_1*0.0125;
#   Lung := ModelValue_1*0.0073;
#   PortalVein := ModelValue_1*0.0058;
#   Stomach := ModelValue_1*0.006;
#   IntestineEnterocytes := ModelValue_1*0.0025;
#   KidneyTissue := ModelValue_1*0.0056;
#   IntestineVascular := ModelValue_1*0.0228;
#   KidneyTubular := ModelValue_1*0.0056;
#   QAdipose := ModelValue_3*0.005;
#   QBrain := ModelValue_3*0.033;
#   QHeart := ModelValue_3*0.066;
#   QKidney := ModelValue_3*0.091;
#   QMuscle := ModelValue_3*0.159;
#   QRemainder := ModelValue_3*0.411;
#   mgLiver := 129.16*(mLiver/Liver)*Compartment_1/1000000;
#   mgIntestineLumen := 129.16*(mIntestineLumen/IntestineLumen)*Compartment_0/1000000;
#   mgBrain := 129.16*(mBrain/Brain)*Compartment_9/1000000;
#   mgAdipose := 129.16*(mAdipose/Adipose)*Compartment_10/1000000;
#   mgHeart := 129.16*(mHeart/Heart)*Compartment_7/1000000;
#   mgKidneyPlasma := 129.16*(mKidneyPlasma/KidneyPlasma)*Compartment_2/1000000;
#   mgRemainder := 129.16*(mRemainder/Remainder)*Compartment_3/1000000;
#   mgMuscle := 129.16*(mMuscle/Muscle)*Compartment_8/1000000;
#   mgPortalVein := 129.16*(mPortalVein/PortalVein)*Compartment_13/1000000;
#   mgUrine := 129.16*(mUrine/Urine)*Compartment_5/1000000;
#   mgFeces := 129.16*(mFeces/Feces)*Compartment_6/1000000;
#   mgIntestineEnterocytes := 129.16*(mIntestineEnterocytes/IntestineEnterocytes)*Compartment_15/1000000;
#   mgPlasmaVenous := 129.16*(mPlasmaVenous/PlasmaVenous)*Compartment_4/1000000;
#   mgPlasmaArterial := 129.16*(mPlasmaArterial/PlasmaArterial)*Compartment_11/1000000;
#   mgLung := 129.16*(mLung/Lung)*Compartment_12/1000000;
#   mgStomach := 129.16*(mStomach/Stomach)*Compartment_14/1000000;
#   QLiverArtery := ModelValue_3*0.02;
#   QStomach := ModelValue_3*0.02;
#   QPortalVein := ModelValue_3*0.06;
#   QIntestineVascular := ModelValue_3*0.135;
#   QLiverOut := ModelValue_47 + ModelValue_34;
#   mIntestineSum := ((mIntestineEnterocytes/IntestineEnterocytes)*Compartment_15 + Compartment_17*(mIntestineVascular/IntestineVascular))/(Compartment_15 + Compartment_17);
#   mKidneySum := (Compartment_2*(mKidneyPlasma/KidneyPlasma) + Compartment_16*(mKidneyTissue/KidneyTissue) + Compartment_19*(mKidneyTubular/KidneyTubular))/(Compartment_2 + Compartment_16 + Compartment_19);
#   mgKidneyTissues := 129.16*Compartment_16*(mKidneyTissue/KidneyTissue)/1000000;
#   mgIntestineVascular := 129.16*(mIntestineVascular/IntestineVascular)*Compartment_17/1000000;
#   mgStomachLumen := 129.16*(mStomachLumen/StomachLumen)*Compartment_18/1000000;
#   QPortalVeinOut := ModelValue_35 + ModelValue_36 + ModelValue_37;
#   mArterialPlasma__for_kidney := mPlasmaArterial/PlasmaArterial;
#   mgKidneyTubular := 129.16*Compartment_19*(mKidneyTubular/KidneyTubular)/1000000;
#   mgKidneyTotal := mgKidneyPlasma + mgKidneyTissues + mgKidneyTubular;
#   mgIntestineTotal := mgIntestineEnterocytes + mgIntestineVascular;
#
#   // Reactions:
#   _03_5__IntestineVascular____PortalVein: mIntestineVascular => mPortalVein; Flow_from_organ(QIntestineVascular, mIntestineVascular/IntestineVascular, Ktp_IntestineVascular);
#   _06_3__Liver____PlasmaVenous: mLiver => mPlasmaVenous; Flow_from_organ(QLiverOut, mLiver/Liver, Ktp_Liver);
#   _13_2__KidneyPlasma____PlasmaVenous: mKidneyPlasma => mPlasmaVenous; Flow_from_organ(QKidney, mKidneyPlasma/KidneyPlasma, Ktp_Kidney);
#   _09_2__Muscle____PlasmaVenous: mMuscle => mPlasmaVenous; Flow_from_organ(QMuscle, mMuscle/Muscle, Ktp_Muscle);
#   _12_2__Remainder____PlasmaVenous: mRemainder => mPlasmaVenous; Flow_from_organ(QRemainder, mRemainder/Remainder, Ktp_Remainder);
#   _02__IntestineLumen____Feces: mIntestineLumen => mFeces; _02__IntestineLumen____Feces_k1*(mIntestineLumen/IntestineLumen);
#   _13_1__PlasmaArterial____KidneyPlasma: mPlasmaArterial => mKidneyPlasma; Flow(QKidney, mPlasmaArterial/PlasmaArterial);
#   _09_1__PlasmaArterial____Muscle: mPlasmaArterial => mMuscle; Flow(QMuscle, mPlasmaArterial/PlasmaArterial);
#   _12_1__PlasmaArterial____Remainder: mPlasmaArterial => mRemainder; Flow(QRemainder, mPlasmaArterial/PlasmaArterial);
#   _13_3__KidneyPlasma____KidneyTubular: mKidneyPlasma => mKidneyTubular; Glomerular(mArterialPlasma__for_kidney, Qgfr);
#   _06_2__PortalVein____Liver: mPortalVein => mLiver; Flow(QPortalVeinOut, mPortalVein/PortalVein);
#   _05_1__PlasmaArterial____Stomach: mPlasmaArterial => mStomach; Flow(QStomach, mPlasmaArterial/PlasmaArterial);
#   _05_2__Stomach____PortalVein: mStomach => mPortalVein; Flow_from_organ(QStomach, mStomach/Stomach, Ktp_Stomach);
#   _04__PlasmaArterial____PortalVein: mPlasmaArterial => mPortalVein; Flow(QPortalVein, mPlasmaArterial/PlasmaArterial);
#   _03_1__PlasmaArterial____IntestineVascular: mPlasmaArterial => mIntestineVascular; Flow(QIntestineVascular, mPlasmaArterial/PlasmaArterial);
#   _06_1__PlasmaArterial____Liver: mPlasmaArterial => mLiver; Flow(QLiverArtery, mPlasmaArterial/PlasmaArterial);
#   _03_2__IntestineLumen____IntestineEnterocytes__PMAT_OCT3: mIntestineLumen => mIntestineEnterocytes; Henri_Michaelis_Menten__irreversible(mIntestineLumen/IntestineLumen, _03_2__IntestineLumen____IntestineEnterocytes__PMAT_OCT3_Km, _03_2__IntestineLumen____IntestineEnterocytes__PMAT_OCT3_V);
#   _03_4__IntestineLumen____IntestineVascular__Saturable: mIntestineLumen => mIntestineVascular; Henri_Michaelis_Menten__irreversible(mIntestineLumen/IntestineLumen, _03_4__IntestineLumen____IntestineVascular__Saturable_Km, _03_4__IntestineLumen____IntestineVascular__Saturable_V);
#   _03_3__IntestineEnterocytes____IntestineVascular__OCT1: mIntestineEnterocytes => mIntestineVascular; Henri_Michaelis_Menten__irreversible(mIntestineEnterocytes/IntestineEnterocytes, _03_3__IntestineEnterocytes____IntestineVascular__OCT1_Km, _03_3__IntestineEnterocytes____IntestineVascular__OCT1_V);
#   _13_4__KidneyPlasma____KidneyTissue: mKidneyPlasma => mKidneyTissue; Henri_Michaelis_Menten__irreversible(mKidneyPlasma/KidneyPlasma, _13_4__KidneyPlasma____KidneyTissue_Km, _13_4__KidneyPlasma____KidneyTissue_V);
#   _13_5__KidneyTissue____KidneyTubular: mKidneyTissue => mKidneyTubular; Henri_Michaelis_Menten__irreversible(mKidneyTissue/KidneyTissue, _13_5__KidneyTissue____KidneyTubular_Km, _13_5__KidneyTissue____KidneyTubular_V);
#   _01__StomachLumen_____IntestineLumen: mStomachLumen => mIntestineLumen; _01__StomachLumen_____IntestineLumen_k1*(mStomachLumen/StomachLumen);
#   _07_2__Lung____PlasmaArterial: mLung => mPlasmaArterial; Flow_from_organ(Cardiac_Output, mLung/Lung, Ktp_Lung);
#   _07_1__PlasmaVenous____Lung: mPlasmaVenous => mLung; Flow(Cardiac_Output, mPlasmaVenous/PlasmaVenous);
#   _08_2__Brain____PlasmaVenous: mBrain => mPlasmaVenous; Flow_from_organ(QBrain, mBrain/Brain, Ktp_Brain);
#   _08_1__PlasmaArterial____Brain: mPlasmaArterial => mBrain; Flow(QBrain, mPlasmaArterial/PlasmaArterial);
#   _11_2__Heart____PlasmaVenous: mHeart => mPlasmaVenous; Flow_from_organ(QHeart, mHeart/Heart, Ktp_Heart);
#   _11_1__PlasmaArterial____Heart: mPlasmaArterial => mHeart; Flow(QHeart, mPlasmaArterial/PlasmaArterial);
#   _10_2__Adipose____PlasmaVenous: mAdipose => mPlasmaVenous; Flow_from_organ(QAdipose, mAdipose/Adipose, Ktp_Adipose);
#   _10_1__PlasmaArterial____Adipose: mPlasmaArterial => mAdipose; Flow(QAdipose, mPlasmaArterial/PlasmaArterial);
#   _13_6__KidneyTubular____UrineExternal: mKidneyTubular => mUrine; _13_6__KidneyTubular____UrineExternal_k1*(mKidneyTubular/KidneyTubular);
#   _03_6__IntestineLumen____IntestineEnterocytes__Diffusion: mIntestineLumen -> mIntestineEnterocytes; _03_6__IntestineLumen____IntestineEnterocytes__Diffusion_k1*(mIntestineLumen/IntestineLumen) - _03_6__IntestineLumen____IntestineEnterocytes__Diffusion_k2*(mIntestineEnterocytes/IntestineEnterocytes);
#   _03_7__IntestineLumen____IntestineVascular__Diffusion: mIntestineLumen -> mIntestineVascular; _03_7__IntestineLumen____IntestineVascular__Diffusion_k1*(mIntestineLumen/IntestineLumen) - _03_7__IntestineLumen____IntestineVascular__Diffusion_k2*(mIntestineVascular/IntestineVascular);
#
#   // Events:
#   Oral_at_0_001: at time > 0.001, t0=false, fromTrigger=false: mStomachLumen = (1000000*ModelValue_0/(129.16*Compartment_18) + mStomachLumen/StomachLumen)*StomachLumen;
#
#   // Species initializations:
#   mLiver = 0;
#   mLiver has substance_per_volume;
#   mKidneyPlasma = 0;
#   mKidneyPlasma has substance_per_volume;
#   mRemainder = 0;
#   mRemainder has substance_per_volume;
#   mPlasmaVenous = (1000000*Metformin_Dose_in_Plasma_in_mg/(129.16*PlasmaVenous))*PlasmaVenous;
#   mPlasmaVenous has substance_per_volume;
#   mHeart = 0;
#   mHeart has substance_per_volume;
#   mMuscle = 0;
#   mMuscle has substance_per_volume;
#   mAdipose = 0;
#   mAdipose has substance_per_volume;
#   mBrain = 0;
#   mBrain has substance_per_volume;
#   mFeces = 0;
#   mFeces has substance_per_volume;
#   mUrine = 0;
#   mUrine has substance_per_volume;
#   mIntestineLumen = 0;
#   mIntestineLumen has substance_per_volume;
#   mPlasmaArterial = 0;
#   mPlasmaArterial has substance_per_volume;
#   mLung = 0;
#   mLung has substance_per_volume;
#   mPortalVein = 0;
#   mPortalVein has substance_per_volume;
#   mStomach = 0;
#   mStomach has substance_per_volume;
#   mIntestineEnterocytes = 0;
#   mIntestineEnterocytes has substance_per_volume;
#   mKidneyTissue = 0;
#   mKidneyTissue has substance_per_volume;
#   mIntestineVascular = 0;
#   mIntestineVascular has substance_per_volume;
#   mStomachLumen = 0;
#   mStomachLumen has substance_per_volume;
#   mKidneyTubular = 0;
#   mKidneyTubular has substance_per_volume;
#
#   // Compartment initializations:
#   IntestineLumen = 0.6;
#   IntestineLumen has volume;
#   Liver has volume;
#   KidneyPlasma has volume;
#   Remainder has volume;
#   PlasmaVenous has volume;
#   Urine = 1;
#   Urine has volume;
#   Feces = 1;
#   Feces has volume;
#   Heart has volume;
#   Muscle has volume;
#   Brain has volume;
#   Adipose has volume;
#   PlasmaArterial has volume;
#   Lung has volume;
#   PortalVein has volume;
#   Stomach has volume;
#   IntestineEnterocytes has volume;
#   KidneyTissue has volume;
#   IntestineVascular has volume;
#   StomachLumen = 0.4;
#   StomachLumen has volume;
#   KidneyTubular has volume;
#
#   // Variable initializations:
#   ModelValue_1 = Body_Weight;
#   Metformin_Dose_in_Plasma_in_mg = 1.375;
#   Metformin_Dose_in_Plasma_in_mg has unit_0;
#   ModelValue_0 = Metformin_Dose_in_Lumen_in_mg;
#   Compartment_18 = StomachLumen;
#   Metformin_Dose_in_Lumen_in_mg = 0;
#   Metformin_Dose_in_Lumen_in_mg has unit_0;
#   Body_Weight = 27.5;
#   Body_Weight has unit_1;
#   Cardiac_Output = 838.8;
#   Cardiac_Output has unit_2;
#   Ktp_Liver = 5.5;
#   Ktp_Brain = 0.8;
#   Ktp_Adipose = 0.73;
#   Ktp_Heart = 2.50008880523789;
#   Ktp_Kidney = 4.5;
#   Ktp_Muscle = 4.1;
#   Ktp_Remainder = 0.8;
#   QAdipose has unit_2;
#   ModelValue_3 = Cardiac_Output;
#   QBrain has unit_2;
#   QHeart has unit_2;
#   QKidney has unit_2;
#   QMuscle has unit_2;
#   QRemainder has unit_2;
#   Compartment_1 = Liver;
#   Compartment_0 = IntestineLumen;
#   Compartment_9 = Brain;
#   Compartment_10 = Adipose;
#   Compartment_7 = Heart;
#   Compartment_2 = KidneyPlasma;
#   Compartment_3 = Remainder;
#   Compartment_8 = Muscle;
#   Compartment_13 = PortalVein;
#   Compartment_5 = Urine;
#   Compartment_6 = Feces;
#   Compartment_15 = IntestineEnterocytes;
#   Ktp_Lung = 3;
#   Compartment_4 = PlasmaVenous;
#   Compartment_11 = PlasmaArterial;
#   Compartment_12 = Lung;
#   Compartment_14 = Stomach;
#   QLiverArtery has unit_2;
#   QStomach has unit_2;
#   QPortalVein has unit_2;
#   QIntestineVascular has unit_2;
#   ModelValue_47 = QPortalVeinOut;
#   ModelValue_34 = QLiverArtery;
#   Ktp_Stomach = 3.20000000001417;
#   Ktp_IntestineVascular = 4.6;
#   Compartment_17 = IntestineVascular;
#   Qgfr = 20;
#   Compartment_16 = KidneyTissue;
#   Compartment_19 = KidneyTubular;
#   ModelValue_35 = QStomach;
#   ModelValue_36 = QPortalVein;
#   ModelValue_37 = QIntestineVascular;
#   _02__IntestineLumen____Feces_k1 = 0.177684;
#   _03_2__IntestineLumen____IntestineEnterocytes__PMAT_OCT3_Km = 900;
#   _03_2__IntestineLumen____IntestineEnterocytes__PMAT_OCT3_V = 1271;
#   _03_4__IntestineLumen____IntestineVascular__Saturable_Km = 60;
#   _03_4__IntestineLumen____IntestineVascular__Saturable_V = 19.2;
#   _03_3__IntestineEnterocytes____IntestineVascular__OCT1_Km = 12300;
#   _03_3__IntestineEnterocytes____IntestineVascular__OCT1_V = 495;
#   _13_4__KidneyPlasma____KidneyTissue_Km = 1380;
#   _13_4__KidneyPlasma____KidneyTissue_V = 87339.5;
#   _13_5__KidneyTissue____KidneyTubular_Km = 230;
#   _13_5__KidneyTissue____KidneyTubular_V = 3000;
#   _01__StomachLumen_____IntestineLumen_k1 = 3.16214;
#   _13_6__KidneyTubular____UrineExternal_k1 = 1.6;
#   _03_6__IntestineLumen____IntestineEnterocytes__Diffusion_k1 = 0.14;
#   _03_6__IntestineLumen____IntestineEnterocytes__Diffusion_k2 = 0.14;
#   _03_7__IntestineLumen____IntestineVascular__Diffusion_k1 = 0.26;
#   _03_7__IntestineLumen____IntestineVascular__Diffusion_k2 = 0.26;
#
#   // Other declarations:
#   var Liver, KidneyPlasma, Remainder, PlasmaVenous, Heart, Muscle, Brain;
#   var Adipose, PlasmaArterial, Lung, PortalVein, Stomach, IntestineEnterocytes;
#   var KidneyTissue, IntestineVascular, KidneyTubular, QAdipose, QBrain, QHeart;
#   var QKidney, QMuscle, QRemainder, mgLiver, mgIntestineLumen, mgBrain, mgAdipose;
#   var mgHeart, mgKidneyPlasma, mgRemainder, mgMuscle, mgPortalVein, mgUrine;
#   var mgFeces, mgIntestineEnterocytes, mgPlasmaVenous, mgPlasmaArterial, mgLung;
#   var mgStomach, QLiverArtery, QStomach, QPortalVein, QIntestineVascular;
#   var QLiverOut, mIntestineSum, mKidneySum, mgKidneyTissues, mgIntestineVascular;
#   var mgStomachLumen, QPortalVeinOut, mArterialPlasma__for_kidney, mgKidneyTubular;
#   var mgKidneyTotal, mgIntestineTotal;
#   const IntestineLumen, ModelValue_1, Urine, Feces, StomachLumen, Metformin_Dose_in_Plasma_in_mg;
#   const ModelValue_0, Compartment_18, Metformin_Dose_in_Lumen_in_mg, Body_Weight;
#   const Cardiac_Output, Ktp_Liver, Ktp_Brain, Ktp_Adipose, Ktp_Heart, Ktp_Kidney;
#   const Ktp_Muscle, Ktp_Remainder, ModelValue_3, Compartment_1, Compartment_0;
#   const Compartment_9, Compartment_10, Compartment_7, Compartment_2, Compartment_3;
#   const Compartment_8, Compartment_13, Compartment_5, Compartment_6, Compartment_15;
#   const Ktp_Lung, Compartment_4, Compartment_11, Compartment_12, Compartment_14;
#   const ModelValue_47, ModelValue_34, Ktp_Stomach, Ktp_IntestineVascular;
#   const Compartment_17, Qgfr, Compartment_16, Compartment_19, ModelValue_35;
#   const ModelValue_36, ModelValue_37;
#
#   // Unit definitions:
#   unit length = metre;
#   unit area = metre^2;
#   unit volume = 1e-3 litre;
#   unit time_unit = time_unit;
#   unit substance = 1e-9 mole;
#   unit unit_0 = 1e-3 gram;
#   unit unit_1 = 1e-3 litre;
#   unit unit_2 = 1e-3 litre / 3600e2 second;
#   unit extent = substance;
#   unit substance_per_volume = 1e-9 mole / 1e-3 litre;
#
#   // Display Names:
#   time_unit is "time";
#   unit_0 is "mg";
#   unit_1 is "ml";
#   unit_2 is "ml/h";
#   ModelValue_1 is "Initial for Body Weight";
#   Metformin_Dose_in_Plasma_in_mg is "Metformin Dose in Plasma in mg";
#   Oral_at_0_001 is "Oral at 0.001";
#   ModelValue_0 is "Initial for Metformin Dose in Lumen in mg";
#   Compartment_18 is "Initial for StomachLumen";
#   Metformin_Dose_in_Lumen_in_mg is "Metformin Dose in Lumen in mg";
#   Body_Weight is "Body Weight";
#   Cardiac_Output is "Cardiac Output";
#   ModelValue_3 is "Initial for Cardiac Output";
#   Compartment_1 is "Initial for Liver";
#   Compartment_0 is "Initial for IntestineLumen";
#   Compartment_9 is "Initial for Brain";
#   Compartment_10 is "Initial for Adipose";
#   Compartment_7 is "Initial for Heart";
#   Compartment_2 is "Initial for KidneyPlasma";
#   Compartment_3 is "Initial for Remainder";
#   Compartment_8 is "Initial for Muscle";
#   Compartment_13 is "Initial for PortalVein";
#   Compartment_5 is "Initial for Urine";
#   Compartment_6 is "Initial for Feces";
#   Compartment_15 is "Initial for IntestineEnterocytes";
#   Compartment_4 is "Initial for PlasmaVenous";
#   Compartment_11 is "Initial for PlasmaArterial";
#   Compartment_12 is "Initial for Lung";
#   Compartment_14 is "Initial for Stomach";
#   ModelValue_47 is "Initial for QPortalVeinOut";
#   ModelValue_34 is "Initial for QLiverArtery";
#   Compartment_17 is "Initial for IntestineVascular";
#   Compartment_16 is "Initial for KidneyTissue";
#   Compartment_19 is "Initial for KidneyTubular";
#   ModelValue_35 is "Initial for QStomach";
#   ModelValue_36 is "Initial for QPortalVein";
#   ModelValue_37 is "Initial for QIntestineVascular";
#   mArterialPlasma__for_kidney is "mArterialPlasma (for kidney)";
#   _03_5__IntestineVascular____PortalVein is "03.5. IntestineVascular -> PortalVein";
#   _06_3__Liver____PlasmaVenous is "06.3. Liver -> PlasmaVenous";
#   _13_2__KidneyPlasma____PlasmaVenous is "13.2. KidneyPlasma -> PlasmaVenous";
#   _09_2__Muscle____PlasmaVenous is "09.2. Muscle -> PlasmaVenous";
#   _12_2__Remainder____PlasmaVenous is "12.2. Remainder -> PlasmaVenous";
#   _02__IntestineLumen____Feces is "02. IntestineLumen -> Feces";
#   _13_1__PlasmaArterial____KidneyPlasma is "13.1. PlasmaArterial -> KidneyPlasma";
#   _09_1__PlasmaArterial____Muscle is "09.1. PlasmaArterial -> Muscle";
#   _12_1__PlasmaArterial____Remainder is "12.1. PlasmaArterial -> Remainder";
#   _13_3__KidneyPlasma____KidneyTubular is "13.3. KidneyPlasma -> KidneyTubular";
#   _06_2__PortalVein____Liver is "06.2. PortalVein -> Liver";
#   _05_1__PlasmaArterial____Stomach is "05.1. PlasmaArterial -> Stomach";
#   _05_2__Stomach____PortalVein is "05.2. Stomach -> PortalVein";
#   _04__PlasmaArterial____PortalVein is "04. PlasmaArterial -> PortalVein";
#   _03_1__PlasmaArterial____IntestineVascular is "03.1. PlasmaArterial -> IntestineVascular";
#   _06_1__PlasmaArterial____Liver is "06.1. PlasmaArterial -> Liver";
#   _03_2__IntestineLumen____IntestineEnterocytes__PMAT_OCT3 is "03.2. IntestineLumen -> IntestineEnterocytes (PMAT OCT3)";
#   _03_4__IntestineLumen____IntestineVascular__Saturable is "03.4. IntestineLumen -> IntestineVascular (Saturable)";
#   _03_3__IntestineEnterocytes____IntestineVascular__OCT1 is "03.3. IntestineEnterocytes -> IntestineVascular (OCT1)";
#   _13_4__KidneyPlasma____KidneyTissue is "13.4. KidneyPlasma -> KidneyTissue";
#   _13_5__KidneyTissue____KidneyTubular is "13.5. KidneyTissue -> KidneyTubular";
#   _01__StomachLumen_____IntestineLumen is "01. StomachLumen  -> IntestineLumen";
#   _07_2__Lung____PlasmaArterial is "07.2. Lung -> PlasmaArterial";
#   _07_1__PlasmaVenous____Lung is "07.1. PlasmaVenous -> Lung";
#   _08_2__Brain____PlasmaVenous is "08.2. Brain -> PlasmaVenous";
#   _08_1__PlasmaArterial____Brain is "08.1. PlasmaArterial -> Brain";
#   _11_2__Heart____PlasmaVenous is "11.2. Heart -> PlasmaVenous";
#   _11_1__PlasmaArterial____Heart is "11.1. PlasmaArterial -> Heart";
#   _10_2__Adipose____PlasmaVenous is "10.2. Adipose -> PlasmaVenous";
#   _10_1__PlasmaArterial____Adipose is "10.1. PlasmaArterial -> Adipose";
#   _13_6__KidneyTubular____UrineExternal is "13.6. KidneyTubular -> UrineExternal";
#   _03_6__IntestineLumen____IntestineEnterocytes__Diffusion is "03.6. IntestineLumen -> IntestineEnterocytes (Diffusion)";
#   _03_7__IntestineLumen____IntestineVascular__Diffusion is "03.7. IntestineLumen -> IntestineVascular (Diffusion)";
#
#   // CV terms:
#   IntestineLumen identity "http://identifiers.org/uberon/UBERON:0018543"
#   Liver identity "http://identifiers.org/uberon/UBERON:0002107"
#   KidneyPlasma identity "http://identifiers.org/ncit/C13356"
#   KidneyPlasma parthood "http://identifiers.org/uberon/UBERON:0002113"
#   Remainder identity "http://identifiers.org/ncit/C37895"
#   PlasmaVenous identity "http://identifiers.org/uberon/UBERON:0004582"
#   Urine identity "http://identifiers.org/uberon/UBERON:0001088"
#   Feces identity "http://identifiers.org/uberon/UBERON:0001245"
#   Heart identity "http://identifiers.org/uberon/UBERON:0000948"
#   Muscle identity "http://identifiers.org/uberon/UBERON:0001630"
#   Brain identity "http://identifiers.org/uberon/UBERON:0000955"
#   Adipose identity "http://identifiers.org/uberon/UBERON:0001013"
#   PlasmaArterial identity "http://identifiers.org/uberon/UBERON:0004572"
#   Lung identity "http://identifiers.org/uberon/UBERON:0002048"
#   PortalVein identity "http://identifiers.org/uberon/UBERON:0002017"
#   Stomach identity "http://identifiers.org/uberon/UBERON:0000945"
#   IntestineEnterocytes identity "http://identifiers.org/bto/BTO:0000398"
#   IntestineEnterocytes parthood "http://identifiers.org/bto/BTO:0000648"
#   KidneyTissue identity "http://identifiers.org/ncit/C12801"
#   KidneyTissue parthood "http://identifiers.org/uberon/UBERON:0002113"
#   IntestineVascular identity "http://identifiers.org/ncit/C13311"
#   IntestineVascular homolog "http://identifiers.org/bto/BTO:0000648"
#   StomachLumen identity "http://identifiers.org/uberon/UBERON:0013525"
#   KidneyTubular identity "http://identifiers.org/uberon/UBERON:0001231"
#   mLiver identity "http://identifiers.org/uberon/UBERON:0002107"
#   mKidneyPlasma identity "http://identifiers.org/ncit/C13356"
#   mKidneyPlasma parthood "http://identifiers.org/uberon/UBERON:0002113"
#   mRemainder identity "http://identifiers.org/ncit/C37895"
#   mPlasmaVenous identity "http://identifiers.org/uberon/UBERON:0004582"
#   mHeart identity "http://identifiers.org/uberon/UBERON:0000948"
#   mMuscle identity "http://identifiers.org/uberon/UBERON:0001630"
#   mAdipose identity "http://identifiers.org/uberon/UBERON:0001013"
#   mBrain identity "http://identifiers.org/uberon/UBERON:0000955"
#   mFeces identity "http://identifiers.org/uberon/UBERON:0001245"
#   mUrine identity "http://identifiers.org/uberon/UBERON:0001088"
#   mIntestineLumen identity "http://identifiers.org/uberon/UBERON:0018543"
#   mPlasmaArterial identity "http://identifiers.org/uberon/UBERON:0004572"
#   mLung identity "http://identifiers.org/uberon/UBERON:0002048"
#   mPortalVein identity "http://identifiers.org/uberon/UBERON:0002017"
#   mStomach identity "http://identifiers.org/uberon/UBERON:0000945"
#   mIntestineEnterocytes identity "http://identifiers.org/bto/BTO:0000398"
#   mIntestineEnterocytes parthood "http://identifiers.org/bto/BTO:0000648"
#   mKidneyTissue identity "http://identifiers.org/ncit/C12801"
#   mKidneyTissue parthood "http://identifiers.org/uberon/UBERON:0002113"
#   mIntestineVascular identity "http://identifiers.org/ncit/C13311"
#   mIntestineVascular parthood "http://identifiers.org/bto/BTO:0000648"
#   mStomachLumen identity "http://identifiers.org/uberon/UBERON:0013525"
#   mKidneyTubular identity "http://identifiers.org/uberon/UBERON:0001231"
#   _03_5__IntestineVascular____PortalVein hypernym "http://identifiers.org/go/GO:0015893"
#   _06_3__Liver____PlasmaVenous hypernym "http://identifiers.org/go/GO:0015893"
#   _13_2__KidneyPlasma____PlasmaVenous hypernym "http://identifiers.org/go/GO:0015893"
#   _09_2__Muscle____PlasmaVenous hypernym "http://identifiers.org/go/GO:0015893"
#   _12_2__Remainder____PlasmaVenous hypernym "http://identifiers.org/go/GO:0015893"
#   _02__IntestineLumen____Feces homolog "http://identifiers.org/go/GO:0015893"
#   _13_1__PlasmaArterial____KidneyPlasma hypernym "http://identifiers.org/go/GO:0015893"
#   _09_1__PlasmaArterial____Muscle hypernym "http://identifiers.org/go/GO:0015893"
#   _12_1__PlasmaArterial____Remainder hypernym "http://identifiers.org/go/GO:0015893"
#   _13_3__KidneyPlasma____KidneyTubular hypernym "http://identifiers.org/go/GO:0015893"
#   _06_2__PortalVein____Liver propertyBearer "http://identifiers.org/go/GO:0015893"
#   _05_1__PlasmaArterial____Stomach hypernym "http://identifiers.org/go/GO:0015893"
#   _05_2__Stomach____PortalVein hypernym "http://identifiers.org/go/GO:0015893"
#   _04__PlasmaArterial____PortalVein hypernym "http://identifiers.org/go/GO:0015893"
#   _03_1__PlasmaArterial____IntestineVascular hypernym "http://identifiers.org/go/GO:0015893"
#   _06_1__PlasmaArterial____Liver propertyBearer "http://identifiers.org/go/GO:0015893"
#   _03_2__IntestineLumen____IntestineEnterocytes__PMAT_OCT3 hypernym "http://identifiers.org/go/GO:0015893"
#   _03_4__IntestineLumen____IntestineVascular__Saturable hypernym "http://identifiers.org/go/GO:0015893"
#   _03_3__IntestineEnterocytes____IntestineVascular__OCT1 hypernym "http://identifiers.org/go/GO:0015893"
#   _13_4__KidneyPlasma____KidneyTissue hypernym "http://identifiers.org/go/GO:0015893"
#   _13_5__KidneyTissue____KidneyTubular hypernym "http://identifiers.org/go/GO:0015893"
#   _01__StomachLumen_____IntestineLumen hypernym "http://identifiers.org/go/GO:0015893"
#   _07_2__Lung____PlasmaArterial hypernym "http://identifiers.org/go/GO:0015893"
#   _07_1__PlasmaVenous____Lung hypernym "http://identifiers.org/go/GO:0015893"
#   _08_2__Brain____PlasmaVenous hypernym "http://identifiers.org/go/GO:0015893"
#   _08_1__PlasmaArterial____Brain hypernym "http://identifiers.org/go/GO:0015893"
#   _11_2__Heart____PlasmaVenous hypernym "http://identifiers.org/go/GO:0015893"
#   _11_1__PlasmaArterial____Heart hypernym "http://identifiers.org/go/GO:0015893"
#   _10_2__Adipose____PlasmaVenous hypernym "http://identifiers.org/go/GO:0015893"
#   _10_1__PlasmaArterial____Adipose hypernym "http://identifiers.org/go/GO:0015893"
#   _13_6__KidneyTubular____UrineExternal hypernym "http://identifiers.org/go/GO:0015893"
#   _03_6__IntestineLumen____IntestineEnterocytes__Diffusion class "http://identifiers.org/go/GO:0015893",
#                                                                  "http://identifiers.org/ncit/C82333"
#   _03_6__IntestineLumen____IntestineEnterocytes__Diffusion hypernym "http://identifiers.org/go/GO:0015893"
#   _03_7__IntestineLumen____IntestineVascular__Diffusion class "http://identifiers.org/go/GO:0015893",
#                                                               "http://identifiers.org/ncit/C82333"
#   _03_7__IntestineLumen____IntestineVascular__Diffusion propertyBearer "http://identifiers.org/go/GO:0015893"
# end
#
# Zake2021___PBPK_model_of_metformin_in_mice__single_dose_intavenous is "Zake2021 - PBPK model of metformin in mice: single dose intavenous"
#
# Zake2021___PBPK_model_of_metformin_in_mice__single_dose_intavenous unknown_model_qual "http://identifiers.org/biomodels.db/MODEL2103020002"
# Zake2021___PBPK_model_of_metformin_in_mice__single_dose_intavenous unknown_model_qual "http://identifiers.org/mamo/MAMO_0000046"
# Zake2021___PBPK_model_of_metformin_in_mice__single_dose_intavenous unknown_model_qual "http://identifiers.org/mamo/MAMO_0000203"
# Zake2021___PBPK_model_of_metformin_in_mice__single_dose_intavenous description "http://identifiers.org/pubmed/33826656"
# Zake2021___PBPK_model_of_metformin_in_mice__single_dose_intavenous model_entity_is "http://identifiers.org/biomodels.db/MODEL2103020002",
#                                                                                    "http://identifiers.org/biomodels.db/BIOMD0000001039"
# Zake2021___PBPK_model_of_metformin_in_mice__single_dose_intavenous container "http://identifiers.org/fma/FMA:7149"
# Zake2021___PBPK_model_of_metformin_in_mice__single_dose_intavenous taxon "http://identifiers.org/taxonomy/10095"
# Zake2021___PBPK_model_of_metformin_in_mice__single_dose_intavenous property "http://identifiers.org/chebi/CHEBI:6801",
#                                                                             "http://identifiers.org/ncit/C38276",
#                                                                             "http://identifiers.org/mamo/MAMO_0000046"

# %%
ctlsb.roadrunner.simulate()
ctlsb.roadrunner.plot()

# %%
METFORMIN_STAIRCASE = ctl.Staircase(initial_value=0, final_value=50, num_step=5)
response_ts = METFORMIN_BUILDER.makeStaircaseResponse(staircase=METFORMIN_STAIRCASE, end_time=20)
METFORMIN_BUILDER.plotStaircaseResponse(response_ts)
# Out:
# /Users/jlheller/home/Technical/repos/controlSBML/src/controlSBML/msgs.py:13: UserWarning:
#
#
#
# ***Warning*** Could not find a steady state. Using current state.

# %%
fitter_result = METFORMIN_BUILDER.fitTransferFunction(num_numerator=2, num_denominator=3, staircase=METFORMIN_STAIRCASE, start_time=0, end_time=30)
METFORMIN_BUILDER.plotFitTransferFunction(fitter_result)
# Out:
# /Users/jlheller/home/Technical/repos/controlSBML/src/controlSBML/msgs.py:13: UserWarning:
#
#
#
# ***Warning*** Could not find a steady state. Using current state.
#
# /Users/jlheller/home/Technical/repos/controlSBML/src/controlSBML/msgs.py:13: UserWarning:
#
#
#
# ***Warning*** Possible numerical instability: max abs residual is 3574.975425

# %%
plt.scatter(fitter_result.time_series["mMuscle"], fitter_result.time_series["predicted"])
plt.plot([0, 4000], [0, 4000], linestyle="--", color="red")

# %%
fitter_result.redchi
# Out:
# 275263.29508874886

# %%
fitter_result.nfev
# Out:
# 235

# %%
fitter_result.stderr
# Out:
# {'n0': 18600.283124841844,
#  'n1': 480329.9544737845,
#  'd0': 681.4281032829349,
#  'd1': 7625.564197424695,
#  'd2': 8254.013333693096}

# %%
fitter_result.transfer_function
# Out:
# TransferFunction(array([0.34115194, 8.81308452]), array([0.01250017, 0.13990931, 0.15144011]))

# %%
fitter_result.transfer_function.poles()
# Out:
# array([-9.97847782+0.j, -1.21411772+0.j])
