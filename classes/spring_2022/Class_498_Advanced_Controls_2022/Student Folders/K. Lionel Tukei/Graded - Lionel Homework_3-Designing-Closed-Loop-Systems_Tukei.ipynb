# %% [markdown]
# # HOMEWORK 3: Designing Closed Loop Systems

# %% [markdown]
# **COMMENTS**
#
# 7/10. There were some oversights, but my main concern is that your answer to Q2 doesn't indicate that you understand what is meant by design. Feel free to reach out to me if you want to have an office hours.

# %% [markdown]
# This homework involves designing a closed loop system with a PID controller.

# %%
# !pip -q install controlSBML
import controlSBML as ctl
import control
from controlSBML.util import makeSimulationTimes
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
import tellurium as te
import sympy
print("controlSBML version: " + ctl.__version__)
# Out:
#      |████████████████████████████████| 398 kB 11.1 MB/s
#      |████████████████████████████████| 8.8 MB 28.8 MB/s
#      |████████████████████████████████| 154 kB 42.8 MB/s
#      |████████████████████████████████| 438 kB 47.4 MB/s
#      |████████████████████████████████| 6.8 MB 763 kB/s
#      |████████████████████████████████| 121 kB 45.1 MB/s
#      |████████████████████████████████| 54 kB 1.9 MB/s
#      |████████████████████████████████| 428 kB 53.2 MB/s
#      |████████████████████████████████| 342 kB 50.1 MB/s
#      |████████████████████████████████| 561 kB 44.4 MB/s
#      |████████████████████████████████| 80 kB 5.8 MB/s
#      |████████████████████████████████| 130 kB 82.2 MB/s
#      |████████████████████████████████| 54 kB 1.6 MB/s
#      |████████████████████████████████| 133 kB 42.5 MB/s
#      |████████████████████████████████| 103 kB 50.2 MB/s
#      |████████████████████████████████| 250 kB 53.3 MB/s
#      |████████████████████████████████| 57 kB 3.9 MB/s
#      |████████████████████████████████| 843 kB 48.4 MB/s
#      |████████████████████████████████| 5.0 MB 40.3 MB/s
#      |████████████████████████████████| 54.8 MB 172 kB/s
#      |████████████████████████████████| 36.7 MB 98 kB/s
#      |████████████████████████████████| 5.6 MB 36.5 MB/s
#      |████████████████████████████████| 3.2 MB 44.3 MB/s
#      |████████████████████████████████| 3.3 MB 38.3 MB/s
#      |████████████████████████████████| 2.1 MB 48.0 MB/s
#      |████████████████████████████████| 2.6 MB 40.3 MB/s
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
#   Building wheel for controlSBML (setup.py) ... done
#   Building wheel for control (setup.py) ... done
#   Building wheel for docstring-expander (setup.py) ... done
#   Building wheel for json5 (setup.py) ... done
#   Building wheel for symmathSBML (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.1.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# controlSBML version: 0.2.20

# %%
# Use the local file if it's available
BIOMD823 = "https://www.ebi.ac.uk/biomodels/model/download/BIOMD0000000823.2?filename=Varusai2018.xml"

# %% [markdown]
# <img src="https://github.com/joseph-hellerstein/advanced-controls-lectures/blob/main/Lecture_13_14-Closed-Loop-Systems/Closed-Loop-System.png?raw=true"
#      alt="Markdown Monster icon" width=600pt
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# **Transfer Functions**
# \begin{eqnarray}
# H_{RY}(s) & = & \frac{Y(s)}{R(s)} & = & \frac{C(s) G(s)}{1 + C(s) G(s) F(s)} \\
# H_{RE}(s) & = & \frac{E(s)}{R(s)} & = & \frac{1}{1 + C(s) G(s) F(s)} \\
# H_{NY}(s) & = & \frac{Y(s)}{N(s)} & = & -\frac{ F(s)}{1 + C(s) G(s) F(s)} \\
# H_{DY}(s) & = & \frac{Y(s)}{D(s)} & = & \frac{ C(s)}{1 + C(s) G(s) F(s)} \\
# \end{eqnarray}

# %% [markdown]
# In this homework, you will design a closed loop system for controlling pDEPTOR in the mTOR system as modelled in BioModels 823.
# Use pAkt as the control input.
# 1. **Build**. (4 pt) Implement the function ``evaluateDesign`` that evaluates the control design of
# a closed loop system for mTOR.
# The evaluation is in the form of a plot of the step response of the system
# to a change in the reference input.
# The plot should include the reference input along with the pAkt and pDEPTO
# values for the closed loop mTOR system. The function has as inputs the design parameters kp, ki, kd.
# 1. **Design**. (2 pt) Use ``evaluateDesign`` to design a system that has no bias for a unit step response in the reference and settles within 10 seconds.
# 1. **Analysis**. (3 pt) Construct the transfer function
# for mTOR from pAkt to pDEPTOR
# and the transfer function $H_{NY} (s)$ for the design parameters you used in (2)
# (Obtain the Jacobian at time 1 from the open loop mTOR system.)
# Use these transfer functions to answer the following questions about how the closed loop system should behave *in theory*.
#    1. Why are large control inputs required to control the mTOR system?
#    1. Why are there no long term oscillations in the closed loop system?
#    1. How will a step increase in noise affect the output of the closed loop system?
# 1. **Discussion**. (1 pt) Plot the values of pAkt for the closed loop system you designed in (2).
# What issues do you see with using this closed loop system in practice?

# %% [markdown]
# # Q1. Build

# %% [markdown]
# ### Viewing the system

# %%
TIMES = ctl.makeSimulationTimes(0, 5, 50)
# Constants
REF = 10

# %%
# See Raw model
ctlsb = ctl.ControlSBML(BIOMD823)
ctlsb.plotTrueModel(figsize=(5,5))

# %% [markdown]
# ### Helper Funtions

# %%
def plotTFs(Gs, kp=0, ki=0, kd=0, times=TIMES, ylim=None, title=None, is_plot=True):
    """
    Constructs the transfer functions for the proportional controller, and filter.
    Calculates the transfer functions HRYs, HREs, HNYs, HDYs and plots them.
    
    Parameters
    ----------
    Gs: control.TransferFunction
    kp: float
    ki: float
    kd: float
    times: list-float
    ylim: (float, float)
        limits of y-values
    title: str
    
    Returns
    -------
    dct
        key: name of transfer function
        value: control.TransferFunction
    """
    Cs = control.TransferFunction([kp], [1]) + control.TransferFunction([ki], [1, 0])  \
        + control.TransferFunction([kd, 0], [1])
    Fs = 1
    denom = 1 + Cs*Gs*Fs
    # Construct the transfer functions
    tf_dct = {
        "HRYs": Cs*Gs/denom,
        "HREs": 1/denom,
        "HNYs": -Fs/denom,
        "HDYs": Cs/denom,
    }
    # Construct the plots
    _, ax = plt.subplots(1)
    for tf in tf_dct.values():
        result = control.forced_response(tf, T=times, U=1)
        plt.plot(result.t.flatten(), result.y.flatten())
    # Refine plots
    plt.legend(list(tf_dct.keys()))
    xmax = max(result.t.flatten())
    plt.plot([0, xmax], [0, 0], linestyle="--", color="black")
    plt.plot([0, xmax], [1, 1], linestyle="--", color="grey")
    plt.ylim([-5, 5])
    title = "kp=%2.2f ki=%2.2f kd=%2.2f" % (kp, ki, kd)
    plt.title(title)
    if not is_plot:
        plt.close()
    return tf_dct
    
# Tests
Gs = control.TransferFunction([2], [1, 3])
dct = plotTFs(Gs, kp=10, ylim=[0, 3], title="Example", is_plot=False)
assert(len(dct) == 4)
assert("TransferFunction" in str(type(dct["HRYs"])))
print("OK!")
# Out:
# OK!

# %%
def makeHRY(model, input_name, output_name, time=0, kp=0, ki=0, kd=0):
    """
    Calculates the transfer function from the reference input to the output.
    
    Parameters
    ----------
    model: str
    input_name: str
    output_name: str
    time: float
    kp: float
    ki: float
    kd: float
    
    Returns
    -------
    control.TransferFunction
    """
    ctlsb = ctl.ControlSBML(model, input_names=[input_name], output_names=[output_name])
    Gs = ctlsb.makeTransferFunction(time=time)
    dct = plotTFs(Gs, kp=kp, ki=ki, kd=kd, is_plot=False)
    return dct["HRYs"]
    
    
# TESTS
tf = makeHRY(BIOMD823, "DEPTOR", "pDEPTOR", kp=0)
assert(tf.dcgain() == 0)
print("OK!")
# Out:
# OK!

# %% [markdown]
# ### Primary Function: evaluateDesign

# %% [markdown]
# **COMMENTS**
#
# I added an argument for the reference value
# and changed "U=5" to "U=ref"

# %%
def evaluateDesign(model=BIOMD823, input_name="pAkt", output_name="pDEPTOR", kp=0, ki=0, kd=0,
               is_plot=True, ref=5):
    """
    Run the testbed and plot the results.
    
    Parameters
    ---------
    model: str
        System under control
    input_name: str
    output_name: str
    kp: float
    ki: float
    kd: float
    is_plot: bool
    ref: float
    
    Results
    -------
    control.InterconnectedSystem
    plot

    """
    # Construct elements of the closed loop system
    factory = ctl.IOSystemFactory()
    
    # Create the elements of the feedback loop
    ctlsb = ctl.ControlSBML(BIOMD823, input_names=[input_name], output_names=[output_name])
    system = ctlsb.makeNonlinearIOSystem("system")
    controller = factory.makePIDController("controller", kp=kp, ki=ki, kd=kd)
    sum_R_F = factory.makeAdder("sum_R_F")

    # Construct the Interconnected system
    system_in = "system.%s" % input_name
    system_out = "system.%s" % output_name

    closed_loop = control.interconnect(
      [system, controller, sum_R_F ], 
      connections=[
        ['controller.in', 'sum_R_F.out'],    # e(t)
        [system_in,   'controller.out'],
        ['sum_R_F.in1', "-" + system_out ],        # y(t)

      ],
      inplist=["sum_R_F.in2"],
      outlist=["sum_R_F.in2", system_in, system_out],
      )

    # Do the simulation and plot
    X0 = ctl.makeStateVector(closed_loop)

    times = ctl.makeSimulationTimes(start_time=0, end_time=10, points_per_time=10)
    # Need the initial state

    result = control.input_output_response(closed_loop, T=times, U=ref, X0=X0)
    plt.plot(result.t, result.outputs[0].flatten())
    plt.plot(result.t, result.outputs[1].flatten())
    plt.plot(result.t, result.outputs[2].flatten())

    plt.ylim([-1, 20])
    legends = ["Reference input ", "pAkt Values", "pDEPTOR Values"]
    plt.legend(legends)
    if not is_plot:
        plt.close()
    #
    return closed_loop, factory

# Tests
interconnect_sys, _ = evaluateDesign(is_plot=False)
assert("Interconnect" in str(type(interconnect_sys)))
print("OK!")
# Out:
# OK!

# %%
_,factory = evaluateDesign(kp=1000,ki=0,kd=0)
factory.report()
# Out:
#         sum_R_F.in1  sum_R_F.in2  sum_R_F.out  controller.in  \
# time
# 0.000      0.000000          5.0     5.000000       5.000000
# 0.001     -0.000147          5.0     4.999853       4.999853
# 0.003     -0.001064          5.0     4.998936       4.998936
# 0.006     -0.002594          5.0     4.997406       4.997406
# 0.008     -0.004583          5.0     4.995417       4.995417
# ...             ...          ...          ...            ...
# 9.900     -4.951976          5.0     0.048024       0.048024
# 9.915     -4.924845          5.0     0.075155       0.075155
# 9.933     -4.912453          5.0     0.087547       0.087547
# 9.962     -4.894616          5.0     0.105384       0.105384
# 10.000    -4.790988          5.0     0.209012       0.209012
#
#         controller.last_err  controller.acc_err  controller.out
# time
# 0.000              0.000000            0.000000     5000.000000
# 0.001              0.070765            0.071272     4999.853492
# 0.003              0.188982            0.192646     4998.935792
# 0.006              0.322714            0.331632     4997.405709
# 0.008              0.385349            0.401078     4995.416971
# ...                     ...                 ...             ...
# 9.900             -0.114171            5.958018       48.024048
# 9.915             -0.059359            5.968268       75.154518
# 9.933             -0.078879            6.017549       87.547167
# 9.962             -0.072874            6.140599      105.384361
# 10.000             0.049127            6.087194      209.012290
#
# [344 rows x 7 columns]

# %%
Gs_BIOMD823 = makeHRY(BIOMD823, "pAkt", "pDEPTOR",  time=1, kp=1, ki=0, kd=0)
BIOMD823_stepmodel = control.forced_response(Gs_BIOMD823,T=TIMES)
plt.plot(BIOMD823_stepmodel.t.flatten(),BIOMD823_stepmodel.outputs.flatten())
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/signal/filter_design.py:1632: BadCoefficients:
#
# Badly conditioned filter coefficients (numerator): the results may be meaningless
#
# /usr/local/lib/python3.7/dist-packages/scipy/signal/filter_design.py:1632: BadCoefficients:
#
# Badly conditioned filter coefficients (numerator): the results may be meaningless

# %% [markdown]
# # Q2. Design

# %% [markdown]
# **COMMENTS**
#
# I'm confused about what you did here. Your evaluateDesign always has the reference input as 5 (U=5), and so your plots are for a reference input of 5. But the question asks you to design for a unit step (U=1). Also, you don't show any control that is unbiased. I can't give you any credit for this question.

# %%
evaluateDesign()
# Out:
# (<InterconnectedSystem:sys[73]:['u[0]']->['y[0]', 'y[1]', 'y[2]']>,
#  <controlSBML.iosystem_factory.IOSystemFactory at 0x7f08ec5eb190>)

# %%
evaluateDesign(BIOMD823, input_name="pAkt", output_name="pDEPTOR", kp=1, ki=0, kd=0)
# Out:
# (<InterconnectedSystem:sys[74]:['u[0]']->['y[0]', 'y[1]', 'y[2]']>,
#  <controlSBML.iosystem_factory.IOSystemFactory at 0x7f08ef467f10>)

# %% [markdown]
# **Joe added the following**

# %% [markdown]
# **COMMENTS**
#
# his is an example of a design that meets the requirements. Note that it makes a difference what the reference value is, and so it's important to have the reference value as an argument to evaluateDesign.

# %%
evaluateDesign(BIOMD823, input_name="pAkt", output_name="pDEPTOR", kp=1000, ki=1, kd=0, ref=1)
# Out:
# (<InterconnectedSystem:sys[709]:['u[0]']->['y[0]', 'y[1]', 'y[2]']>,
#  <controlSBML.iosystem_factory.IOSystemFactory at 0x7f08ec42cb50>)

# %% [markdown]
# # Q3. Analyze

# %% [markdown]
# ### Part 1

# %%
Gs_BIOMD823 = makeHRY(BIOMD823, "pAkt", "pDEPTOR",  time=1, kp=1000, ki=0, kd=0)
Gs_BIOMD823
# Out:
# TransferFunction(array([-8.88178420e-012,  2.89351852e+001,  4.77394308e+002,
#         2.94616749e+003,  8.57841210e+003,  1.26199432e+004,
#         1.03580168e+004,  4.98025853e+003,  1.40437964e+003,
#         2.22617142e+002,  1.85649050e+001,  8.72075691e-001,
#         2.40993321e-002,  3.89802214e-004,  3.42115023e-006,
#         1.26001512e-008,  2.16596209e-022,  1.66064495e-038,
#        -1.53432180e-054, -3.43980909e-073,  8.38306090e-089,
#        -2.87936072e-105,  5.98163681e-124, -7.43297205e-140,
#         0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#         0.00000000e+000,  0.00000000e+000,  0.00000000e+000]), array([ 1.00000000e+000,  2.30701720e+001,  2.42603579e+002,
#         1.49953083e+003,  5.67963788e+003,  1.28189484e+004,
#         1.66398081e+004,  1.27649464e+004,  5.89701622e+003,
#         1.62198632e+003,  2.53241734e+002,  2.09635743e+001,
#         9.80895753e-001,  2.70435401e-002,  4.36767813e-004,
#         3.82938855e-006,  1.40931601e-008,  2.16829493e-022,
#         1.65946509e-038, -1.53596699e-054, -2.72183055e-073,
#         8.38699605e-089, -2.87565414e-105,  6.00187916e-124,
#        -7.42833701e-140,  0.00000000e+000,  0.00000000e+000,
#         0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#         0.00000000e+000]))

# %%
print("The DC gain of the system is", Gs_BIOMD823.dcgain(), " and the poles are ", Gs_BIOMD823.pole())
# Out:
# The DC gain of the system is nan  and the poles are  [-3.28571236e+00+4.64411980e+00j -3.28571236e+00-4.64411980e+00j
#  -5.99999615e+00+0.00000000e+00j -3.96034302e+00+0.00000000e+00j
#  -3.96034170e+00+0.00000000e+00j -5.71428571e-01+0.00000000e+00j
#  -5.01657639e-01+1.46395901e-06j -5.01657639e-01-1.46395901e-06j
#  -4.28571428e-01+9.12170172e-07j -4.28571428e-01-9.12170172e-07j
#  -3.30898952e-02+0.00000000e+00j -3.30898227e-02+0.00000000e+00j
#  -2.00181061e-02+0.00000000e+00j -1.99999807e-02+1.80867673e-05j
#  -1.99999807e-02-1.80867673e-05j -1.99819324e-02+0.00000000e+00j
#  -1.53080565e-14+0.00000000e+00j -1.31311647e-16+0.00000000e+00j
#   5.39998459e-17+0.00000000e+00j -1.37881623e-17+0.00000000e+00j
#   7.26416506e-18+1.20070512e-21j  7.26416506e-18-1.20070512e-21j
#  -4.07353318e-19+0.00000000e+00j -4.06165328e-19+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j
#   0.00000000e+00+0.00000000e+00j  0.00000000e+00+0.00000000e+00j]

# %%
kp = 1000
ki = 0
kd = 0
Cs = control.TransferFunction([kp], [1]) + control.TransferFunction([ki], [1, 0])  \
        + control.TransferFunction([kd, 0], [1])
Fs = 1
denom = 1 + Cs*Gs*Fs
HNYs = -Fs/denom
print("The DC gain of noise is", int(HNYs.dcgain()), " and the poles are ", HNYs.pole())
print("The transfer function of noise is", HNYs)
# Out:
# The DC gain of noise is 0  and the poles are  [-2003.+0.j]
# The transfer function of noise is
#  -s - 3
# --------
# s + 2003

# %% [markdown]
# ##### Plot Transfer functions

# %%
plotTFs(Gs_BIOMD823, kp=1000, ki=0, kd=0, times=TIMES, ylim=None, title=None, is_plot=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.02209e-17): result may not be accurate.
# {'HDYs': TransferFunction(array([ 1.00000000e+003,  2.30701720e+004,  2.42603579e+005,
#          1.49953083e+006,  5.67963788e+006,  1.28189484e+007,
#          1.66398081e+007,  1.27649464e+007,  5.89701622e+006,
#          1.62198632e+006,  2.53241734e+005,  2.09635743e+004,
#          9.80895753e+002,  2.70435401e+001,  4.36767813e-001,
#          3.82938855e-003,  1.40931601e-005,  2.16829493e-019,
#          1.65946509e-035, -1.53596699e-051, -2.72183055e-070,
#          8.38699605e-086, -2.87565414e-102,  6.00187916e-121,
#         -7.42833701e-137,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000]), array([ 1.00000000e+000,  2.30701720e+001,  2.91777888e+004,
#          4.78893839e+005,  2.95184713e+006,  8.59123105e+006,
#          1.26365830e+007,  1.03707818e+007,  4.98615555e+006,
#          1.40600163e+006,  2.22870384e+005,  1.85858686e+004,
#          8.73056587e+002,  2.41263756e+001,  3.90238981e-001,
#          3.42497962e-003,  1.26142443e-005,  2.16813039e-019,
#          1.66230441e-035, -1.53585777e-051, -3.44253092e-070,
#          8.39144790e-086, -2.88223638e-102,  5.98763869e-121,
#         -7.44040038e-137,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000])),
#  'HNYs': TransferFunction(array([-1.00000000e+000, -2.30701720e+001, -2.42603579e+002,
#         -1.49953083e+003, -5.67963788e+003, -1.28189484e+004,
#         -1.66398081e+004, -1.27649464e+004, -5.89701622e+003,
#         -1.62198632e+003, -2.53241734e+002, -2.09635743e+001,
#         -9.80895753e-001, -2.70435401e-002, -4.36767813e-004,
#         -3.82938855e-006, -1.40931601e-008, -2.16829493e-022,
#         -1.65946509e-038,  1.53596699e-054,  2.72183055e-073,
#         -8.38699605e-089,  2.87565414e-105, -6.00187916e-124,
#          7.42833701e-140,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000]), array([ 1.00000000e+000,  2.30701720e+001,  2.91777888e+004,
#          4.78893839e+005,  2.95184713e+006,  8.59123105e+006,
#          1.26365830e+007,  1.03707818e+007,  4.98615555e+006,
#          1.40600163e+006,  2.22870384e+005,  1.85858686e+004,
#          8.73056587e+002,  2.41263756e+001,  3.90238981e-001,
#          3.42497962e-003,  1.26142443e-005,  2.16813039e-019,
#          1.66230441e-035, -1.53585777e-051, -3.44253092e-070,
#          8.39144790e-086, -2.88223638e-102,  5.98763869e-121,
#         -7.44040038e-137,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000])),
#  'HREs': TransferFunction(array([ 1.00000000e+000,  2.30701720e+001,  2.42603579e+002,
#          1.49953083e+003,  5.67963788e+003,  1.28189484e+004,
#          1.66398081e+004,  1.27649464e+004,  5.89701622e+003,
#          1.62198632e+003,  2.53241734e+002,  2.09635743e+001,
#          9.80895753e-001,  2.70435401e-002,  4.36767813e-004,
#          3.82938855e-006,  1.40931601e-008,  2.16829493e-022,
#          1.65946509e-038, -1.53596699e-054, -2.72183055e-073,
#          8.38699605e-089, -2.87565414e-105,  6.00187916e-124,
#         -7.42833701e-140,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000]), array([ 1.00000000e+000,  2.30701720e+001,  2.91777888e+004,
#          4.78893839e+005,  2.95184713e+006,  8.59123105e+006,
#          1.26365830e+007,  1.03707818e+007,  4.98615555e+006,
#          1.40600163e+006,  2.22870384e+005,  1.85858686e+004,
#          8.73056587e+002,  2.41263756e+001,  3.90238981e-001,
#          3.42497962e-003,  1.26142443e-005,  2.16813039e-019,
#          1.66230441e-035, -1.53585777e-051, -3.44253092e-070,
#          8.39144790e-086, -2.88223638e-102,  5.98763869e-121,
#         -7.44040038e-137,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000])),
#  'HRYs': TransferFunction(array([-8.88178420e-009,  2.89351852e+004,  1.14493401e+006,
#          2.09795158e+007,  2.35753773e+008,  1.80548502e+009,
#          9.88287018e+009,  3.95035117e+010,  1.16355335e+011,
#          2.53704152e+011,  4.11631035e+011,  5.00876952e+011,
#          4.61091882e+011,  3.23475387e+011,  1.73687226e+011,
#          7.14219694e+010,  2.24176253e+010,  5.33342629e+009,
#          9.52654265e+008,  1.26556368e+008,  1.24467080e+007,
#          9.10022729e+005,  4.99005667e+004,  2.06970189e+003,
#          6.52622420e+001,  1.56412122e+000,  2.82885351e-002,
#          3.79708517e-004,  3.66734087e-006,  2.40977990e-008,
#          9.64656927e-011,  1.77575949e-013,  5.78460945e-027,
#          4.74075786e-041,  7.15412963e-057, -3.89800891e-073,
#         -5.10997936e-089,  2.38270545e-105,  2.48271155e-123,
#         -3.52629608e-139,  8.77080186e-156,  4.49705332e-174,
#         -2.54786380e-190,  8.42631103e-207, -1.59095202e-224,
#          4.27994197e-241, -8.90454141e-260,  5.52146213e-276,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000]), array([ 1.00000000e+000,  4.61403440e+001,  2.99526252e+004,
#          1.15912688e+006,  2.11189204e+007,  2.36769054e+008,
#          1.81111416e+009,  9.90691690e+009,  3.95828893e+010,
#          1.16557322e+011,  2.54098713e+011,  4.12221129e+011,
#          5.01553076e+011,  4.61687076e+011,  3.23879106e+011,
#          1.73898489e+011,  7.15071298e+010,  2.24439434e+010,
#          5.33961241e+009,  9.53748972e+008,  1.26700778e+008,
#          1.24608379e+007,  9.11051986e+005,  4.99568524e+004,
#          2.07203171e+003,  6.53355935e+001,  1.56587711e+000,
#          2.83202620e-002,  3.80134051e-004,  3.67144824e-006,
#          2.41247741e-008,  9.65736291e-011,  1.77774566e-013,
#          5.79072108e-027,  4.74550614e-041,  7.16128276e-057,
#         -3.90191602e-073, -5.11508870e-089,  2.38509190e-105,
#          2.48508422e-123, -3.52982360e-139,  8.77957773e-156,
#          4.50134375e-174, -2.55040875e-190,  8.43472153e-207,
#         -1.59254324e-224,  4.28421784e-241, -8.91345821e-260,
#          5.52698015e-276,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000,  0.00000000e+000,  0.00000000e+000,
#          0.00000000e+000]))}

# %%
result = control.forced_response(HNYs, T=TIMES, U=1)
plt.plot(result.t.flatten(), result.y.flatten())
plt.title("Noise transfer funtion plot")
# Out:
# Text(0.5, 1.0, 'Noise transfer funtion plot')

# %% [markdown]
# ##### Plots  of the transfer function at the kp = 1000 and the alteration of the control values  (Seems that kd changes make the system unstable)

# %%
for kp in [1, 10, 1000]:
    for ki in [1, 10, 1000]:
      for kd in [0, 0, 0]:
          title = "kp: %2.1f ki: %2.1f ld: %2.1f" % (kp, ki, kd)
          _ = plotTFs(Gs_BIOMD823, kp=kp, ki=ki, kd=kd, title=title, ylim=[-1, 30])
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=6.37027e-19): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=6.37027e-19): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=6.37027e-19): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=9.91074e-17): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=9.91074e-17): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=9.91074e-17): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=6.26964e-19): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=6.26964e-19): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=6.26964e-19): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.02041e-17): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.02041e-17): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.02041e-17): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.00552e-17): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.00552e-17): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=1.00552e-17): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=2.77501e-18): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=2.77501e-18): result may not be accurate.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/scipy/sparse/linalg/matfuncs.py:709: LinAlgWarning:
#
# Ill-conditioned matrix (rcond=2.77501e-18): result may not be accurate.

# %% [markdown]
# ### Part 2

# %% [markdown]
# #### Jacobian

# %%
OP_TIME =  1
BIOMD823_JACOBIAN = ctlsb.getJacobian(OP_TIME)
BIOMD823_JACOBIAN
# Out:
#                      IR       pIR  IRS      pIRS  iIRS  Akt      pAkt  mTORC1  \
# IR            -0.004518  0.028571  0.0  0.000000  0.00  0.0  0.000000    0.00
# pIR            0.004518 -0.028571  0.0  0.000000  0.00  0.0  0.000000    0.00
# IRS            0.000000 -0.066667  0.0  0.020000  0.02  0.0  0.000000    0.00
# pIRS           0.000000  0.066667  0.0 -0.020000  0.00  0.0  0.000000    0.00
# iIRS           0.000000  0.000000  0.0  0.000000 -0.02  0.0  0.000000    0.00
# Akt            0.000000  0.000000  0.0 -0.046729  0.00  0.0  0.058824    0.00
# pAkt           0.000000  0.000000  0.0  0.046729  0.00  0.0 -0.058824    0.00
# mTORC1         0.000000  0.000000  0.0  0.000000  0.00  0.0 -0.099206   -0.35
# pmTORC1        0.000000  0.000000  0.0  0.000000  0.00  0.0  0.099206    0.00
# mTORC2         0.000000 -0.166667  0.0  0.000000  0.00  0.0  0.000000    0.00
# pmTORC2        0.000000  0.166667  0.0  0.000000  0.00  0.0  0.000000    0.00
# imTORC2        0.000000  0.000000  0.0  0.000000  0.00  0.0  0.000000    0.00
# mTORC1_DEPTOR  0.000000  0.000000  0.0  0.000000  0.00  0.0  0.000000    0.35
# mTORC2_DEPTOR  0.000000  0.000000  0.0  0.000000  0.00  0.0  0.000000    0.00
# DEPTOR         0.000000  0.000000  0.0  0.000000  0.00  0.0  0.000000   -0.35
# pDEPTOR        0.000000  0.000000  0.0  0.000000  0.00  0.0  0.000000    0.00
#
#                 pmTORC1  mTORC2   pmTORC2  imTORC2  mTORC1_DEPTOR  \
# IR             0.000000    0.00  0.000000      0.0          0.000
# pIR            0.000000    0.00  0.000000      0.0          0.000
# IRS           -0.066667    0.00  0.000000      0.0          0.000
# pIRS           0.000000    0.00  0.000000      0.0          0.000
# iIRS           0.066667    0.00  0.000000      0.0          0.000
# Akt            0.000000    0.00 -1.442308      0.0          0.000
# pAkt           0.000000    0.00  1.442308      0.0          0.000
# mTORC1         5.999996    0.00  0.000000      0.0          0.006
# pmTORC1       -5.999996    0.00  0.000000      0.0          0.000
# mTORC2         0.000000   -2.45  0.428571      0.0          0.000
# pmTORC2        0.000000    0.00 -0.428571      0.0          0.000
# imTORC2        0.000000    0.00  0.000000      0.0          0.000
# mTORC1_DEPTOR  0.000000    0.00  0.000000      0.0         -0.006
# mTORC2_DEPTOR  0.000000    2.45  0.000000      0.0          0.000
# DEPTOR        -0.291667   -2.45 -0.126039      0.0          0.006
# pDEPTOR        0.291667    0.00  0.126039      0.0          0.000
#
#                mTORC2_DEPTOR  DEPTOR   pDEPTOR
# IR                     0.000    0.00  0.000000
# pIR                    0.000    0.00  0.000000
# IRS                    0.000    0.00  0.000000
# pIRS                   0.000    0.00  0.000000
# iIRS                   0.000    0.00  0.000000
# Akt                    0.000    0.00  0.000000
# pAkt                   0.000    0.00  0.000000
# mTORC1                 0.000   -0.25  0.000000
# pmTORC1                0.000    0.00  0.000000
# mTORC2                 0.006   -1.40  0.000000
# pmTORC2                0.000    0.00  0.000000
# imTORC2                0.000    0.00  0.000000
# mTORC1_DEPTOR          0.000    0.25  0.000000
# mTORC2_DEPTOR         -0.006    1.40  0.000000
# DEPTOR                 0.006   -1.65  0.571429
# pDEPTOR                0.000    0.00 -0.571429

# %% [markdown]
# #### (1) Large control inputs are required because the mTOR system has other reactions that keep the system at certain levels and basically resistant to pertabations

# %% [markdown]
# **COMMENTS**
#
# The answer must make reference to the poles. I took off 1 pt.

# %% [markdown]
# #### (2) They are no long term osilations because the poles of the system are quite small

# %% [markdown]
# #### (3) The DC gain of noise is 0 therefore it would have no effect on the input

# %% [markdown]
# # Q4. Discussion

# %%
pAkt_values, _ = evaluateDesign(BIOMD823, input_name="pAkt", output_name="pDEPTOR", kp=1000, ki=0, kd=0, is_plot=False)
X0 = ctl.makeStateVector(pAkt_values)
times = ctl.makeSimulationTimes(start_time=0, end_time=50, points_per_time=10)
result = control.input_output_response(pAkt_values, T=times, U=6, X0=X0)
plt.plot(result.t, result.outputs[1].flatten())
legends = ["pAkt values"]
plt.legend(legends)
plt.title("Values of pAkt")
# Out:
# Text(0.5, 1.0, 'Values of pAkt')

# %% [markdown]
# #### The primary issuse I see is having to have high values to change the system  while trying to minimize to complexity that the funtions must solve to yeild the output values. At the same time increasing Kp will add osilations to our system.
